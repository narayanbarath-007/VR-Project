# %%
# %pip install torch
# %pip install torchvision
# %pip install torchsummary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /home/barath/.local/lib/python3.10/site-packages (2.2.1+cu118)
# Requirement already satisfied: nvidia-cudnn-cu11==8.7.0.84 in /home/barath/.local/lib/python3.10/site-packages (from torch) (8.7.0.84)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home/barath/.local/lib/python3.10/site-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home/barath/.local/lib/python3.10/site-packages (from torch) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home/barath/.local/lib/python3.10/site-packages (from torch) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home/barath/.local/lib/python3.10/site-packages (from torch) (11.7.5.86)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch) (1.9)
# Requirement already satisfied: triton==2.2.0 in /home/barath/.local/lib/python3.10/site-packages (from torch) (2.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages/Jinja2-3.1.2-py3.10.egg (from torch) (3.1.2)
# Requirement already satisfied: networkx in /home/barath/.local/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home/barath/.local/lib/python3.10/site-packages (from torch) (11.11.3.6)
# Requirement already satisfied: nvidia-nccl-cu11==2.19.3 in /home/barath/.local/lib/python3.10/site-packages (from torch) (2.19.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home/barath/.local/lib/python3.10/site-packages (from torch) (11.8.87)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/barath/.local/lib/python3.10/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/barath/.local/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: fsspec in /home/barath/.local/lib/python3.10/site-packages (from torch) (2023.12.2)
# Requirement already satisfied: filelock in /home/barath/.local/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home/barath/.local/lib/python3.10/site-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home/barath/.local/lib/python3.10/site-packages (from torch) (11.8.86)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/barath/.local/lib/python3.10/site-packages (from jinja2->torch) (2.1.4)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torchvision in /home/barath/.local/lib/python3.10/site-packages (0.17.1+cu118)
# Requirement already satisfied: torch==2.2.1 in /home/barath/.local/lib/python3.10/site-packages (from torchvision) (2.2.1+cu118)
# Requirement already satisfied: numpy in /home/barath/.local/lib/python3.10/site-packages (from torchvision) (1.26.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/barath/.local/lib/python3.10/site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (11.8.89)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (11.11.3.6)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (11.8.87)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages/Jinja2-3.1.2-py3.10.egg (from torch==2.2.1->torchvision) (3.1.2)
# Requirement already satisfied: fsspec in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (2023.12.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (4.9.0)
# Requirement already satisfied: triton==2.2.0 in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (2.2.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.7.0.84 in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (8.7.0.84)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (11.8.89)
# Requirement already satisfied: filelock in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (3.13.1)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch==2.2.1->torchvision) (1.9)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (10.9.0.58)
# Requirement already satisfied: networkx in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (3.2.1)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (11.8.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.19.3 in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (2.19.3)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (11.4.1.48)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (10.3.0.86)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /home/barath/.local/lib/python3.10/site-packages (from torch==2.2.1->torchvision) (11.7.5.86)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/barath/.local/lib/python3.10/site-packages (from jinja2->torch==2.2.1->torchvision) (2.1.4)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torchsummary in /home/barath/.local/lib/python3.10/site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch 
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import transforms,datasets
from torchsummary import summary
import torch.optim as optim
import os
import datetime

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# #### Load CIFAR-10 dataset

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [01:35<00:00, 1782002.46it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# #### CNN Architecture

# %%
import torch.nn as nn

class CNN(nn.Module):
    def __init__(self, activation):
        super(CNN, self).__init__()
        self.activation = activation
        
        # First convolutional layer
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # Second convolutional layer
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # Flatten layer
        self.flatten = nn.Flatten()
        
        # Fully connected layers
        self.fc1 = nn.Linear(8192, 1024) # 8192 = 128 * (32 // 4) * (32 // 4) (Height, Width are halved twice, cause of max pooling)
        self.bn_fc1 = nn.BatchNorm1d(1024)
        self.fc2 = nn.Linear(1024, 10)
        
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        # First convolutional layer
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.activation(x)
        x = self.pool1(x)
        
        # Second convolutional layer
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.activation(x)
        x = self.pool2(x)
        
        # Flatten layer
        x = self.flatten(x)
        
        # Fully connected layers
        x = self.fc1(x)
        x = self.bn_fc1(x)
        x = self.activation(x)
        
        x = self.fc2(x)
        x = self.softmax(x)
        
        return x

# %% [markdown]
# #### Function to train the model

# %%
def train_model(model, criterion, optimizer, train_loader, epochs,model_save_path):
    # Log the model summary
    summary(model, (3, 32, 32), device=str(device))

    start_time =  datetime.datetime.now()

    training_losses = []
    
    for epoch in range(epochs):
        running_loss = 0.0
        for data, target in train_loader:
            data, target = data.to(device), target.to(device)
            
            #reset the gradient
            optimizer.zero_grad()
            
            #Forward Propogation
            output = model(data)
            
            loss = criterion(output, target)
            #Backpropogate
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()

        avg_loss = running_loss / len(train_loader)
        print(f'Epoch {epoch + 1}/{epochs}, Loss: {avg_loss}')
        training_losses.append((epoch + 1, avg_loss))
        
    end_time = datetime.datetime.now()
    
    training_time = end_time - start_time
    print(f"Training Time: {training_time} seconds")
    
    # Save the trained model parameters
    torch.save(model.state_dict(), model_save_path)
    print(f"Model parameters saved to: {model_save_path}")
    
    return training_losses

# %% [markdown]
# #### Function to evaluate model

# %%
def evaluate_model(model, test_loader):
    model.eval()
    
    correct = 0
    total = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()

    accuracy = correct / total
    print(f'Test Accuracy: {accuracy}')

# %%
import matplotlib.pyplot as plt

def plot_training_losses(training_losses, save_path=None):
    epochs, losses = zip(*training_losses)
    plt.plot(epochs, losses, label='Training Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training Loss vs. Epoch')
    
    # Set x-axis ticks to integer values only
    plt.xticks(range(min(epochs), max(epochs)+1))
    
    plt.legend()
    
    if save_path:
        plt.savefig(save_path)
        print(f"Plot saved to: {save_path}")
    plt.show()

# %% [markdown]
# #### Function to load the model

# %%
def load_model(model, file_path):
    model.load_state_dict(torch.load(file_path))
    model.eval()  # Set the model to evaluation mode
    return model

# %%
results_folder_path = 'results'
os.makedirs(results_folder_path, exist_ok=True)

# %%
results_second_architecture = "results/first architecture"
os.makedirs(results_second_architecture,exist_ok=True)

# %% [markdown]
# ### ReLU Activation function

# %% [markdown]
# #### 1. ReLU without momentum

# %%
relu_wo_momentum = CNN(nn.ReLU()).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(relu_wo_momentum.parameters(),lr=0.001)

result_relu_wo_momentum_folder = "results/first architecture/relu_wo_momentum"
os.makedirs(result_relu_wo_momentum_folder,exist_ok=True)
relu_wo_momentum_save_path = os.path.join(result_relu_wo_momentum_folder, 'model.pth')

relu_wo_momentum_losses = train_model(relu_wo_momentum, criterion, optimizer, train_loader, epochs=20,model_save_path=relu_wo_momentum_save_path)
# Out:
# /home/barath/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#        BatchNorm2d-6          [-1, 128, 16, 16]             256
#               ReLU-7          [-1, 128, 16, 16]               0
#          MaxPool2d-8            [-1, 128, 8, 8]               0
#            Flatten-9                 [-1, 8192]               0
#            Linear-10                 [-1, 1024]       8,389,632
#       BatchNorm1d-11                 [-1, 1024]           2,048
#              ReLU-12                 [-1, 1024]               0
#            Linear-13                   [-1, 10]          10,250
#           Softmax-14                   [-1, 10]               0
# ================================================================
# Total params: 8,477,962
# Trainable params: 8,477,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 2.52
# Params size (MB): 32.34
# Estimated Total Size (MB): 34.88
# ----------------------------------------------------------------
# Epoch 1/20, Loss: 2.2297863350499925
# Epoch 2/20, Loss: 2.148121123728545
# Epoch 3/20, Loss: 2.1023597148678186
# Epoch 4/20, Loss: 2.0689295566905184
# Epoch 5/20, Loss: 2.0443774862667485
# Epoch 6/20, Loss: 2.024279038009741
# Epoch 7/20, Loss: 2.007161371085955
# Epoch 8/20, Loss: 1.9917164092783428
# Epoch 9/20, Loss: 1.9784057526027454
# Epoch 10/20, Loss: 1.9654076617697012
# Epoch 11/20, Loss: 1.9534720904991756
# Epoch 12/20, Loss: 1.9424557629448678
# Epoch 13/20, Loss: 1.9312751090435116
# Epoch 14/20, Loss: 1.920971184435403
# Epoch 15/20, Loss: 1.9115278618719878
# Epoch 16/20, Loss: 1.903424916517399
# Epoch 17/20, Loss: 1.8941658880094738
# Epoch 18/20, Loss: 1.8870495548638542
# Epoch 19/20, Loss: 1.8788400792404818
# Epoch 20/20, Loss: 1.8712160791582464
# Training Time: 0:05:10.757177 seconds
# Model parameters saved to: results/first architecture/relu_wo_momentum/model.pth

# %%
relu_wo_momentum_training_losses_save_path = os.path.join(result_relu_wo_momentum_folder, 'training_losses_plot')
plot_training_losses(relu_wo_momentum_losses,relu_wo_momentum_training_losses_save_path)
# Out:
# Plot saved to: results/first architecture/relu_wo_momentum/training_losses_plot

# %%
loaded_relu_wo_momentum_model = load_model(relu_wo_momentum, relu_wo_momentum_save_path)
loaded_relu_wo_momentum_model = loaded_relu_wo_momentum_model.to(device)
evaluate_model(loaded_relu_wo_momentum_model,test_loader)
# Out:
# Test Accuracy: 0.6128

# %% [markdown]
# #### 2. ReLU with momentum

# %%
result_relu_w_momentum_folder = "results/first architecture/relu_w_momentum"
os.makedirs(result_relu_w_momentum_folder,exist_ok=True)

relu_mom_arr = [0.5, 0.7, 0.9] #momentum is a hyper parameter, we could try various values 

for mom in relu_mom_arr:
    print('ReLu with momentum - '+str(mom)+'\n')
    relu_w_momentum = CNN(nn.ReLU()).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(relu_w_momentum.parameters(),lr=0.001,momentum=mom)
    relu_w_momentum_save_path = os.path.join(result_relu_w_momentum_folder, 'model_mom=' + str(int(10*mom)) +'.pth')
    relu_w_momentum_training_loss = train_model(relu_w_momentum, criterion, optimizer, train_loader, epochs=20, model_save_path=relu_w_momentum_save_path)
    
    relu_w_momentum_training_loss_save_path = os.path.join(result_relu_w_momentum_folder, 'model_mom=' + str(int(10*mom)))
    plot_training_losses(relu_w_momentum_training_loss,relu_w_momentum_training_loss_save_path)
# Out:
# ReLu with momentum - 0.5
#
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv2d: 1-1                            [-1, 64, 32, 32]          1,792
# ├─BatchNorm2d: 1-2                       [-1, 64, 32, 32]          128
# ├─ReLU: 1-3                              [-1, 64, 32, 32]          --
# ├─MaxPool2d: 1-4                         [-1, 64, 16, 16]          --
# ├─Conv2d: 1-5                            [-1, 128, 16, 16]         73,856
# ├─BatchNorm2d: 1-6                       [-1, 128, 16, 16]         256
# ├─ReLU: 1-7                              [-1, 128, 16, 16]         --
# ├─MaxPool2d: 1-8                         [-1, 128, 8, 8]           --
# ├─Flatten: 1-9                           [-1, 8192]                --
# ├─Linear: 1-10                           [-1, 1024]                8,389,632
# ├─BatchNorm1d: 1-11                      [-1, 1024]                2,048
# ├─ReLU: 1-12                             [-1, 1024]                --
# ├─Linear: 1-13                           [-1, 10]                  10,250
# ├─Softmax: 1-14                          [-1, 10]                  --
# ==========================================================================================
# Total params: 8,477,962
# Trainable params: 8,477,962
# Non-trainable params: 0
# Total mult-adds (M): 29.04
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.52
# Params size (MB): 32.34
# Estimated Total Size (MB): 33.87
# ==========================================================================================
# Epoch 1/20, Loss: 2.182070471441654
# Epoch 2/20, Loss: 2.0746986186108014
# Epoch 3/20, Loss: 2.032148028426158
# Epoch 4/20, Loss: 1.9999162948040097
# Epoch 5/20, Loss: 1.9716364883096016
# Epoch 6/20, Loss: 1.9468528462188017
# Epoch 7/20, Loss: 1.9261735321005897
# Epoch 8/20, Loss: 1.906756219351688
# Epoch 9/20, Loss: 1.8882827155120538
# Epoch 10/20, Loss: 1.8722370315695662
# Epoch 11/20, Loss: 1.8588611103994461
# Epoch 12/20, Loss: 1.8443124308000745
# Epoch 13/20, Loss: 1.8312629462812868
# Epoch 14/20, Loss: 1.819478504035784
# Epoch 15/20, Loss: 1.8086454778376138
# Epoch 16/20, Loss: 1.7976710302445589
# Epoch 17/20, Loss: 1.7894344174343606
# Epoch 18/20, Loss: 1.7806205760182627
# Epoch 19/20, Loss: 1.7720336828695233
# Epoch 20/20, Loss: 1.7647695454490153
# Training Time: 0:05:49.550670 seconds
# Model parameters saved to: results/first architecture/relu_w_momentum/model_mom=5.pth
# Plot saved to: results/first architecture/relu_w_momentum/model_mom=5
# ReLu with momentum - 0.7
#
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv2d: 1-1                            [-1, 64, 32, 32]          1,792
# ├─BatchNorm2d: 1-2                       [-1, 64, 32, 32]          128
# ├─ReLU: 1-3                              [-1, 64, 32, 32]          --
# ├─MaxPool2d: 1-4                         [-1, 64, 16, 16]          --
# ├─Conv2d: 1-5                            [-1, 128, 16, 16]         73,856
# ├─BatchNorm2d: 1-6                       [-1, 128, 16, 16]         256
# ├─ReLU: 1-7                              [-1, 128, 16, 16]         --
# ├─MaxPool2d: 1-8                         [-1, 128, 8, 8]           --
# ├─Flatten: 1-9                           [-1, 8192]                --
# ├─Linear: 1-10                           [-1, 1024]                8,389,632
# ├─BatchNorm1d: 1-11                      [-1, 1024]                2,048
# ├─ReLU: 1-12                             [-1, 1024]                --
# ├─Linear: 1-13                           [-1, 10]                  10,250
# ├─Softmax: 1-14                          [-1, 10]                  --
# ==========================================================================================
# Total params: 8,477,962
# Trainable params: 8,477,962
# Non-trainable params: 0
# Total mult-adds (M): 29.04
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.52
# Params size (MB): 32.34
# Estimated Total Size (MB): 33.87
# ==========================================================================================
# Epoch 1/20, Loss: 2.1494493196382547
# Epoch 2/20, Loss: 2.0378323660787108
# Epoch 3/20, Loss: 1.9893387077409592
# Epoch 4/20, Loss: 1.9526161046894006
# Epoch 5/20, Loss: 1.923489736016754
# Epoch 6/20, Loss: 1.8968072640316567
# Epoch 7/20, Loss: 1.8712192409483672
# Epoch 8/20, Loss: 1.8484283106406327
# Epoch 9/20, Loss: 1.8289822436049772
# Epoch 10/20, Loss: 1.8112232137823958
# Epoch 11/20, Loss: 1.7968694273468173
# Epoch 12/20, Loss: 1.7817610339130587
# Epoch 13/20, Loss: 1.7701480443520314
# Epoch 14/20, Loss: 1.7578736100050494
# Epoch 15/20, Loss: 1.7479037740041532
# Epoch 16/20, Loss: 1.7365703210806298
# Epoch 17/20, Loss: 1.7276421085647915
# Epoch 18/20, Loss: 1.7180489190399189
# Epoch 19/20, Loss: 1.7091969029068033
# Epoch 20/20, Loss: 1.7002350802311812
# Training Time: 0:05:58.880436 seconds
# Model parameters saved to: results/first architecture/relu_w_momentum/model_mom=7.pth
# Plot saved to: results/first architecture/relu_w_momentum/model_mom=7
# ReLu with momentum - 0.9
#
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv2d: 1-1                            [-1, 64, 32, 32]          1,792
# ├─BatchNorm2d: 1-2                       [-1, 64, 32, 32]          128
# ├─ReLU: 1-3                              [-1, 64, 32, 32]          --
# ├─MaxPool2d: 1-4                         [-1, 64, 16, 16]          --
# ├─Conv2d: 1-5                            [-1, 128, 16, 16]         73,856
# ├─BatchNorm2d: 1-6                       [-1, 128, 16, 16]         256
# ├─ReLU: 1-7                              [-1, 128, 16, 16]         --
# ├─MaxPool2d: 1-8                         [-1, 128, 8, 8]           --
# ├─Flatten: 1-9                           [-1, 8192]                --
# ├─Linear: 1-10                           [-1, 1024]                8,389,632
# ├─BatchNorm1d: 1-11                      [-1, 1024]                2,048
# ├─ReLU: 1-12                             [-1, 1024]                --
# ├─Linear: 1-13                           [-1, 10]                  10,250
# ├─Softmax: 1-14                          [-1, 10]                  --
# ==========================================================================================
# Total params: 8,477,962
# Trainable params: 8,477,962
# Non-trainable params: 0
# Total mult-adds (M): 29.04
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.52
# Params size (MB): 32.34
# Estimated Total Size (MB): 33.87
# ==========================================================================================
# Epoch 1/20, Loss: 2.062557149421224
# Epoch 2/20, Loss: 1.9203656270071063
# Epoch 3/20, Loss: 1.8544722867133978
# Epoch 4/20, Loss: 1.808136382218822
# Epoch 5/20, Loss: 1.7746828106967993
# Epoch 6/20, Loss: 1.7502136870723246
# Epoch 7/20, Loss: 1.725572527674458
# Epoch 8/20, Loss: 1.7055010967852209
# Epoch 9/20, Loss: 1.6866197613499048
# Epoch 10/20, Loss: 1.668842108200883
# Epoch 11/20, Loss: 1.6522105372775242
# Epoch 12/20, Loss: 1.6367564904110512
# Epoch 13/20, Loss: 1.623244868824854
# Epoch 14/20, Loss: 1.6101212204264863
# Epoch 15/20, Loss: 1.597122172717853
# Epoch 16/20, Loss: 1.5874880431863048
# Epoch 17/20, Loss: 1.5778475004388852
# Epoch 18/20, Loss: 1.5692597098667602
# Epoch 19/20, Loss: 1.5608586543966132
# Epoch 20/20, Loss: 1.5535563352467763
# Training Time: 0:06:16.070244 seconds
# Model parameters saved to: results/first architecture/relu_w_momentum/model_mom=9.pth
# Plot saved to: results/first architecture/relu_w_momentum/model_mom=9

# %% [markdown]
# evaluate the trained models

# %%
for mom in relu_mom_arr:
    print('ReLu with momentum - '+str(mom))
    relu_w_momentum_save_path = os.path.join(result_relu_w_momentum_folder, 'model_mom=' + str(int(10*mom)) +'.pth')
    loaded_relu_w_momentum_model = load_model(relu_w_momentum, relu_w_momentum_save_path)
    loaded_relu_w_momentum_model = loaded_relu_w_momentum_model.to(device)
    evaluate_model(loaded_relu_w_momentum_model,test_loader)
    print('\n')
# Out:
# ReLu with momentum - 0.5
# Test Accuracy: 0.6907
#
#
# ReLu with momentum - 0.7
# Test Accuracy: 0.7138
#
#
# ReLu with momentum - 0.9
# Test Accuracy: 0.7417

# %% [markdown]
# #### 3. ReLU with Adam

# %%
relu_w_adam = CNN(nn.ReLU()).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(relu_w_adam.parameters(),lr=0.001)

result_relu_w_adam_folder = "results/first architecture/relu_w_adam"
os.makedirs(result_relu_w_adam_folder, exist_ok=True)
relu_w_adam_save_path = os.path.join(result_relu_w_adam_folder, 'model.pth')

relu_w_adam_losses = train_model(relu_w_adam, criterion, optimizer, train_loader, epochs=20,model_save_path=relu_w_adam_save_path)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#        BatchNorm2d-6          [-1, 128, 16, 16]             256
#               ReLU-7          [-1, 128, 16, 16]               0
#          MaxPool2d-8            [-1, 128, 8, 8]               0
#            Flatten-9                 [-1, 8192]               0
#            Linear-10                 [-1, 1024]       8,389,632
#       BatchNorm1d-11                 [-1, 1024]           2,048
#              ReLU-12                 [-1, 1024]               0
#            Linear-13                   [-1, 10]          10,250
#           Softmax-14                   [-1, 10]               0
# ================================================================
# Total params: 8,477,962
# Trainable params: 8,477,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 2.52
# Params size (MB): 32.34
# Estimated Total Size (MB): 34.88
# ----------------------------------------------------------------
# Epoch 1/20, Loss: 1.9168650634453426
# Epoch 2/20, Loss: 1.7970982779322378
# Epoch 3/20, Loss: 1.7489626366464073
# Epoch 4/20, Loss: 1.7086379999090033
# Epoch 5/20, Loss: 1.676180781458345
# Epoch 6/20, Loss: 1.6503793960032256
# Epoch 7/20, Loss: 1.6264179964809466
# Epoch 8/20, Loss: 1.6053206893184302
# Epoch 9/20, Loss: 1.584816260563443
# Epoch 10/20, Loss: 1.5716514345020285
# Epoch 11/20, Loss: 1.5602933820861076
# Epoch 12/20, Loss: 1.5498665261756428
# Epoch 13/20, Loss: 1.543430693466645
# Epoch 14/20, Loss: 1.5347665162647472
# Epoch 15/20, Loss: 1.5294116319292952
# Epoch 16/20, Loss: 1.5244503066972699
# Epoch 17/20, Loss: 1.520048160687127
# Epoch 18/20, Loss: 1.5164354724042557
# Epoch 19/20, Loss: 1.513937316587209
# Epoch 20/20, Loss: 1.5129584241706087
# Training Time: 0:05:57.424673 seconds
# Model parameters saved to: results/first architecture/relu_w_adam/model.pth

# %%
relu_w_adam_training_losses_save_path = os.path.join(result_relu_w_adam_folder, 'training_losses_plot')
plot_training_losses(relu_w_adam_losses,relu_w_adam_training_losses_save_path)
# Out:
# Plot saved to: results/first architecture/relu_w_adam/training_losses_plot

# %%
loaded_relu_w_adam_model = load_model(relu_w_adam, relu_w_adam_save_path)
loaded_relu_w_adam_model = loaded_relu_w_adam_model.to(device)
evaluate_model(loaded_relu_w_adam_model,test_loader)
# Out:
# Test Accuracy: 0.7687

# %% [markdown]
# ### Tanh Activation function

# %% [markdown]
# #### 1. Tanh without momentum

# %%
tanh_wo_momentum = CNN(nn.Tanh()).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(tanh_wo_momentum.parameters(),lr=0.001)

result_tanh_wo_momentum_folder = "results/first architecture/tanh_wo_momentum"
os.makedirs(result_tanh_wo_momentum_folder,exist_ok=True)
tanh_wo_momentum_save_path = os.path.join(result_tanh_wo_momentum_folder, 'model.pth')

tanh_wo_momentum_losses = train_model(tanh_wo_momentum, criterion, optimizer, train_loader, epochs=20,model_save_path=tanh_wo_momentum_save_path)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               Tanh-3           [-1, 64, 32, 32]               0
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#        BatchNorm2d-6          [-1, 128, 16, 16]             256
#               Tanh-7          [-1, 128, 16, 16]               0
#          MaxPool2d-8            [-1, 128, 8, 8]               0
#            Flatten-9                 [-1, 8192]               0
#            Linear-10                 [-1, 1024]       8,389,632
#       BatchNorm1d-11                 [-1, 1024]           2,048
#              Tanh-12                 [-1, 1024]               0
#            Linear-13                   [-1, 10]          10,250
#           Softmax-14                   [-1, 10]               0
# ================================================================
# Total params: 8,477,962
# Trainable params: 8,477,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 2.52
# Params size (MB): 32.34
# Estimated Total Size (MB): 34.88
# ----------------------------------------------------------------
# Epoch 1/20, Loss: 2.2060258842795095
# Epoch 2/20, Loss: 2.114830990276678
# Epoch 3/20, Loss: 2.0736430761454354
# Epoch 4/20, Loss: 2.048834227235116
# Epoch 5/20, Loss: 2.030587061439329
# Epoch 6/20, Loss: 2.016213684740579
# Epoch 7/20, Loss: 2.003924739940087
# Epoch 8/20, Loss: 1.992237180547641
# Epoch 9/20, Loss: 1.9826414095776161
# Epoch 10/20, Loss: 1.9736938144239928
# Epoch 11/20, Loss: 1.9648246013599893
# Epoch 12/20, Loss: 1.956934544131579
# Epoch 13/20, Loss: 1.9490628579388494
# Epoch 14/20, Loss: 1.941577168834179
# Epoch 15/20, Loss: 1.9347641114383707
# Epoch 16/20, Loss: 1.9274998452047558
# Epoch 17/20, Loss: 1.920985151892123
# Epoch 18/20, Loss: 1.9143668493956252
# Epoch 19/20, Loss: 1.9087285876578992
# Epoch 20/20, Loss: 1.9020598962178925
# Training Time: 0:05:04.416784 seconds
# Model parameters saved to: results/first architecture/relu_wo_momentum/model.pth

# %%
tanh_wo_momentum_training_losses_save_path = os.path.join(result_tanh_wo_momentum_folder, 'training_losses_plot')
plot_training_losses(tanh_wo_momentum_losses,tanh_wo_momentum_training_losses_save_path)
# Out:
# Plot saved to: results/first architecture/relu_wo_momentum/training_losses_plot

# %%
loaded_tanh_wo_momentum_model = load_model(tanh_wo_momentum, tanh_wo_momentum_save_path)
loaded_tanh_wo_momentum_model = loaded_tanh_wo_momentum_model.to(device)
evaluate_model(loaded_tanh_wo_momentum_model,test_loader)
# Out:
# Test Accuracy: 0.5744

# %% [markdown]
# #### 2. Tanh with momentum

# %%
result_tanh_w_momentum_folder = "results/first architecture/tanh_w_momentum"
os.makedirs(result_tanh_w_momentum_folder,exist_ok=True)

tanh_mom_arr = [0.5, 0.7, 0.9] #momentum is a hyper parameter, we could try various values 

for mom in tanh_mom_arr:
    print('tanh with momentum - '+str(mom)+'\n')
    tanh_w_momentum = CNN(nn.Tanh()).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(tanh_w_momentum.parameters(),lr=0.001,momentum=mom)
    tanh_w_momentum_save_path = os.path.join(result_tanh_w_momentum_folder, 'model_mom=' + str(int(10*mom)) +'.pth')
    tanh_w_momentum_training_loss = train_model(tanh_w_momentum, criterion, optimizer, train_loader, epochs=20, model_save_path=tanh_w_momentum_save_path)
    
    tanh_w_momentum_training_loss_save_path = os.path.join(result_tanh_w_momentum_folder, 'model_mom=' + str(int(10*mom)))
    plot_training_losses(tanh_w_momentum_training_loss,tanh_w_momentum_training_loss_save_path)
# Out:
# tanh with momentum - 0.5
#
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv2d: 1-1                            [-1, 64, 32, 32]          1,792
# ├─BatchNorm2d: 1-2                       [-1, 64, 32, 32]          128
# ├─Tanh: 1-3                              [-1, 64, 32, 32]          --
# ├─MaxPool2d: 1-4                         [-1, 64, 16, 16]          --
# ├─Conv2d: 1-5                            [-1, 128, 16, 16]         73,856
# ├─BatchNorm2d: 1-6                       [-1, 128, 16, 16]         256
# ├─Tanh: 1-7                              [-1, 128, 16, 16]         --
# ├─MaxPool2d: 1-8                         [-1, 128, 8, 8]           --
# ├─Flatten: 1-9                           [-1, 8192]                --
# ├─Linear: 1-10                           [-1, 1024]                8,389,632
# ├─BatchNorm1d: 1-11                      [-1, 1024]                2,048
# ├─Tanh: 1-12                             [-1, 1024]                --
# ├─Linear: 1-13                           [-1, 10]                  10,250
# ├─Softmax: 1-14                          [-1, 10]                  --
# ==========================================================================================
# Total params: 8,477,962
# Trainable params: 8,477,962
# Non-trainable params: 0
# Total mult-adds (M): 29.04
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.52
# Params size (MB): 32.34
# Estimated Total Size (MB): 33.87
# ==========================================================================================
# Epoch 1/20, Loss: 2.1695928070551296
# Epoch 2/20, Loss: 2.073514909847923
# Epoch 3/20, Loss: 2.0363484227748785
# Epoch 4/20, Loss: 2.0115680193047387
# Epoch 5/20, Loss: 1.991465342014342
# Epoch 6/20, Loss: 1.9741658923571066
# Epoch 7/20, Loss: 1.9596857513917987
# Epoch 8/20, Loss: 1.9452829778651752
# Epoch 9/20, Loss: 1.9315806098301391
# Epoch 10/20, Loss: 1.918189033218052
# Epoch 11/20, Loss: 1.9058641257798274
# Epoch 12/20, Loss: 1.8936975168450105
# Epoch 13/20, Loss: 1.8824392348299246
# Epoch 14/20, Loss: 1.8713154971142254
# Epoch 15/20, Loss: 1.8607611762898049
# Epoch 16/20, Loss: 1.850968263338289
# Epoch 17/20, Loss: 1.841992946079625
# Epoch 18/20, Loss: 1.8326267484203933
# Epoch 19/20, Loss: 1.8236664596116146
# Epoch 20/20, Loss: 1.8160215419576602
# Training Time: 0:06:05.467679 seconds
# Model parameters saved to: results/first architecture/tanh_w_momentum/model_mom=5.pth
# Plot saved to: results/first architecture/tanh_w_momentum/model_mom=5
# tanh with momentum - 0.7
#
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv2d: 1-1                            [-1, 64, 32, 32]          1,792
# ├─BatchNorm2d: 1-2                       [-1, 64, 32, 32]          128
# ├─Tanh: 1-3                              [-1, 64, 32, 32]          --
# ├─MaxPool2d: 1-4                         [-1, 64, 16, 16]          --
# ├─Conv2d: 1-5                            [-1, 128, 16, 16]         73,856
# ├─BatchNorm2d: 1-6                       [-1, 128, 16, 16]         256
# ├─Tanh: 1-7                              [-1, 128, 16, 16]         --
# ├─MaxPool2d: 1-8                         [-1, 128, 8, 8]           --
# ├─Flatten: 1-9                           [-1, 8192]                --
# ├─Linear: 1-10                           [-1, 1024]                8,389,632
# ├─BatchNorm1d: 1-11                      [-1, 1024]                2,048
# ├─Tanh: 1-12                             [-1, 1024]                --
# ├─Linear: 1-13                           [-1, 10]                  10,250
# ├─Softmax: 1-14                          [-1, 10]                  --
# ==========================================================================================
# Total params: 8,477,962
# Trainable params: 8,477,962
# Non-trainable params: 0
# Total mult-adds (M): 29.04
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.52
# Params size (MB): 32.34
# Estimated Total Size (MB): 33.87
# ==========================================================================================
# Epoch 1/20, Loss: 2.1307159697308258
# Epoch 2/20, Loss: 2.036710395532496
# Epoch 3/20, Loss: 2.0006826837044542
# Epoch 4/20, Loss: 1.9732545115758695
# Epoch 5/20, Loss: 1.9510266773231195
# Epoch 6/20, Loss: 1.9300596401514605
# Epoch 7/20, Loss: 1.909832656535956
# Epoch 8/20, Loss: 1.8905009964238042
# Epoch 9/20, Loss: 1.8725281523926485
# Epoch 10/20, Loss: 1.8549142298491106
# Epoch 11/20, Loss: 1.8389565783083592
# Epoch 12/20, Loss: 1.8254858522159059
# Epoch 13/20, Loss: 1.8122275429003685
# Epoch 14/20, Loss: 1.7990998453496363
# Epoch 15/20, Loss: 1.7881185458139386
# Epoch 16/20, Loss: 1.7767946890857824
# Epoch 17/20, Loss: 1.7681777957455276
# Epoch 18/20, Loss: 1.759121854744299
# Epoch 19/20, Loss: 1.7496403710311637
# Epoch 20/20, Loss: 1.7418903328878494
# Training Time: 0:05:46.421930 seconds
# Model parameters saved to: results/first architecture/tanh_w_momentum/model_mom=7.pth
# Plot saved to: results/first architecture/tanh_w_momentum/model_mom=7
# tanh with momentum - 0.9
#
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv2d: 1-1                            [-1, 64, 32, 32]          1,792
# ├─BatchNorm2d: 1-2                       [-1, 64, 32, 32]          128
# ├─Tanh: 1-3                              [-1, 64, 32, 32]          --
# ├─MaxPool2d: 1-4                         [-1, 64, 16, 16]          --
# ├─Conv2d: 1-5                            [-1, 128, 16, 16]         73,856
# ├─BatchNorm2d: 1-6                       [-1, 128, 16, 16]         256
# ├─Tanh: 1-7                              [-1, 128, 16, 16]         --
# ├─MaxPool2d: 1-8                         [-1, 128, 8, 8]           --
# ├─Flatten: 1-9                           [-1, 8192]                --
# ├─Linear: 1-10                           [-1, 1024]                8,389,632
# ├─BatchNorm1d: 1-11                      [-1, 1024]                2,048
# ├─Tanh: 1-12                             [-1, 1024]                --
# ├─Linear: 1-13                           [-1, 10]                  10,250
# ├─Softmax: 1-14                          [-1, 10]                  --
# ==========================================================================================
# Total params: 8,477,962
# Trainable params: 8,477,962
# Non-trainable params: 0
# Total mult-adds (M): 29.04
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.52
# Params size (MB): 32.34
# Estimated Total Size (MB): 33.87
# ==========================================================================================
# Epoch 1/20, Loss: 2.0669263852831654
# Epoch 2/20, Loss: 1.963562840086115
# Epoch 3/20, Loss: 1.9145526703056472
# Epoch 4/20, Loss: 1.8738897525136122
# Epoch 5/20, Loss: 1.840628763293976
# Epoch 6/20, Loss: 1.8142392004237455
# Epoch 7/20, Loss: 1.7905839733455493
# Epoch 8/20, Loss: 1.7697471712556336
# Epoch 9/20, Loss: 1.7525645206346536
# Epoch 10/20, Loss: 1.738574640067947
# Epoch 11/20, Loss: 1.7225292623805268
# Epoch 12/20, Loss: 1.7100989977112206
# Epoch 13/20, Loss: 1.6977328148949178
# Epoch 14/20, Loss: 1.6848254420263382
# Epoch 15/20, Loss: 1.6742383456596024
# Epoch 16/20, Loss: 1.6621742432989428
# Epoch 17/20, Loss: 1.6536719847823043
# Epoch 18/20, Loss: 1.641328190446205
# Epoch 19/20, Loss: 1.6327095328999297
# Epoch 20/20, Loss: 1.6243870081499105
# Training Time: 0:05:49.387009 seconds
# Model parameters saved to: results/first architecture/tanh_w_momentum/model_mom=9.pth
# Plot saved to: results/first architecture/tanh_w_momentum/model_mom=9

# %% [markdown]
# evaluate the trained models

# %%
for mom in tanh_mom_arr:
    print('tanh with momentum - '+str(mom))
    tanh_w_momentum_save_path = os.path.join(result_tanh_w_momentum_folder, 'model_mom=' + str(int(10*mom)) +'.pth')
    loaded_tanh_w_momentum_model = load_model(tanh_w_momentum, tanh_w_momentum_save_path)
    loaded_tanh_w_momentum_model = loaded_tanh_w_momentum_model.to(device)
    evaluate_model(loaded_tanh_w_momentum_model,test_loader)
    print('\n')
# Out:
# tanh with momentum - 0.5
# Test Accuracy: 0.6342
#
#
# tanh with momentum - 0.7
# Test Accuracy: 0.6738
#
#
# tanh with momentum - 0.9
# Test Accuracy: 0.6852

# %% [markdown]
# #### 3. Tanh with Adam

# %%
tanh_w_adam = CNN(nn.Tanh()).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(tanh_w_adam.parameters(),lr=0.001)

result_tanh_w_adam_folder = "results/first architecture/tanh_w_adam"
os.makedirs(result_tanh_w_adam_folder, exist_ok=True)
tanh_w_adam_save_path = os.path.join(result_tanh_w_adam_folder, 'model.pth')

tanh_w_adam_losses = train_model(tanh_w_adam, criterion, optimizer, train_loader, epochs=20,model_save_path=tanh_w_adam_save_path)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               Tanh-3           [-1, 64, 32, 32]               0
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#        BatchNorm2d-6          [-1, 128, 16, 16]             256
#               Tanh-7          [-1, 128, 16, 16]               0
#          MaxPool2d-8            [-1, 128, 8, 8]               0
#            Flatten-9                 [-1, 8192]               0
#            Linear-10                 [-1, 1024]       8,389,632
#       BatchNorm1d-11                 [-1, 1024]           2,048
#              Tanh-12                 [-1, 1024]               0
#            Linear-13                   [-1, 10]          10,250
#           Softmax-14                   [-1, 10]               0
# ================================================================
# Total params: 8,477,962
# Trainable params: 8,477,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 2.52
# Params size (MB): 32.34
# Estimated Total Size (MB): 34.88
# ----------------------------------------------------------------
# Epoch 1/20, Loss: 1.9871228488205035
# Epoch 2/20, Loss: 1.8894606962838136
# Epoch 3/20, Loss: 1.8445131043948786
# Epoch 4/20, Loss: 1.8141063017308559
# Epoch 5/20, Loss: 1.7839791425658613
# Epoch 6/20, Loss: 1.7638577414900445
# Epoch 7/20, Loss: 1.7408338958954872
# Epoch 8/20, Loss: 1.7254934176764525
# Epoch 9/20, Loss: 1.7116920755952216
# Epoch 10/20, Loss: 1.6957343485959047
# Epoch 11/20, Loss: 1.681604771357973
# Epoch 12/20, Loss: 1.6699028257518778
# Epoch 13/20, Loss: 1.6565088538257666
# Epoch 14/20, Loss: 1.6441083934605885
# Epoch 15/20, Loss: 1.6297835899740838
# Epoch 16/20, Loss: 1.621088564243463
# Epoch 17/20, Loss: 1.6112096971258179
# Epoch 18/20, Loss: 1.6028937650153705
# Epoch 19/20, Loss: 1.5954555297446678
# Epoch 20/20, Loss: 1.587524414367383
# Training Time: 0:06:04.092275 seconds
# Model parameters saved to: results/first architecture/tanh_w_adam/model.pth

# %%
tanh_w_adam_training_losses_save_path = os.path.join(result_tanh_w_adam_folder, 'training_losses_plot')
plot_training_losses(tanh_w_adam_losses,tanh_w_adam_training_losses_save_path)
# Out:
# Plot saved to: results/first architecture/tanh_w_adam/training_losses_plot

# %%
loaded_tanh_w_adam_model = load_model(tanh_w_adam, tanh_w_adam_save_path)
loaded_tanh_w_adam_model = loaded_tanh_w_adam_model.to(device)
evaluate_model(loaded_tanh_w_adam_model,test_loader)
# Out:
# Test Accuracy: 0.7216

# %% [markdown]
# ### Sigmoid Activation function

# %% [markdown]
# #### 1. Sigmoid without momentum

# %%
sigmoid_wo_momentum = CNN(nn.Sigmoid()).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(sigmoid_wo_momentum.parameters(),lr=0.001)

result_sigmoid_wo_momentum_folder = "results/first architecture/relu_wo_momentum"
os.makedirs(result_sigmoid_wo_momentum_folder,exist_ok=True)
sigmoid_wo_momentum_save_path = os.path.join(result_sigmoid_wo_momentum_folder, 'model.pth')

sigmoid_wo_momentum_losses = train_model(sigmoid_wo_momentum, criterion, optimizer, train_loader, epochs=20,model_save_path=sigmoid_wo_momentum_save_path)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#            Sigmoid-3           [-1, 64, 32, 32]               0
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#        BatchNorm2d-6          [-1, 128, 16, 16]             256
#            Sigmoid-7          [-1, 128, 16, 16]               0
#          MaxPool2d-8            [-1, 128, 8, 8]               0
#            Flatten-9                 [-1, 8192]               0
#            Linear-10                 [-1, 1024]       8,389,632
#       BatchNorm1d-11                 [-1, 1024]           2,048
#           Sigmoid-12                 [-1, 1024]               0
#            Linear-13                   [-1, 10]          10,250
#           Softmax-14                   [-1, 10]               0
# ================================================================
# Total params: 8,477,962
# Trainable params: 8,477,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 2.52
# Params size (MB): 32.34
# Estimated Total Size (MB): 34.88
# ----------------------------------------------------------------
# Epoch 1/20, Loss: 2.2851959960844814
# Epoch 2/20, Loss: 2.2524666731314893
# Epoch 3/20, Loss: 2.228003189386919
# Epoch 4/20, Loss: 2.209695248347719
# Epoch 5/20, Loss: 2.195316146401798
# Epoch 6/20, Loss: 2.184269816674235
# Epoch 7/20, Loss: 2.174972196978986
# Epoch 8/20, Loss: 2.1671623735476637
# Epoch 9/20, Loss: 2.1605922093476786
# Epoch 10/20, Loss: 2.1540450568089398
# Epoch 11/20, Loss: 2.1489724225705236
# Epoch 12/20, Loss: 2.1436504817679713
# Epoch 13/20, Loss: 2.139351557892607
# Epoch 14/20, Loss: 2.1346547502995756
# Epoch 15/20, Loss: 2.1305299797631285
# Epoch 16/20, Loss: 2.1261069763956777
# Epoch 17/20, Loss: 2.1224563733086255
# Epoch 18/20, Loss: 2.1165952638287067
# Epoch 19/20, Loss: 2.1112868761467505
# Epoch 20/20, Loss: 2.1053909331636356
# Training Time: 0:05:17.263050 seconds
# Model parameters saved to: results/first architecture/relu_wo_momentum/model.pth

# %%
sigmoid_wo_momentum_training_losses_save_path = os.path.join(result_sigmoid_wo_momentum_folder, 'training_losses_plot')
plot_training_losses(sigmoid_wo_momentum_losses,sigmoid_wo_momentum_training_losses_save_path)
# Out:
# Plot saved to: results/first architecture/relu_wo_momentum/training_losses_plot

# %%
loaded_sigmoid_wo_momentum_model = load_model(sigmoid_wo_momentum, sigmoid_wo_momentum_save_path)
loaded_sigmoid_wo_momentum_model = loaded_sigmoid_wo_momentum_model.to(device)
evaluate_model(loaded_sigmoid_wo_momentum_model,test_loader)
# Out:
# Test Accuracy: 0.4004

# %% [markdown]
# #### 2. Sigmoid with momentum

# %%
result_sigmoid_w_momentum_folder = "results/first architecture/sigmoid_w_momentum"
os.makedirs(result_sigmoid_w_momentum_folder,exist_ok=True)

sigmoid_mom_arr = [0.5, 0.7, 0.9] #momentum is a hyper parameter, we could try various values 

for mom in sigmoid_mom_arr:
    print('sigmoid with momentum - '+str(mom)+'\n')
    sigmoid_w_momentum = CNN(nn.Sigmoid()).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(sigmoid_w_momentum.parameters(),lr=0.001,momentum=mom)
    sigmoid_w_momentum_save_path = os.path.join(result_sigmoid_w_momentum_folder, 'model_mom=' + str(int(10*mom)) +'.pth')
    print(sigmoid_w_momentum_save_path)
    sigmoid_w_momentum_training_loss = train_model(sigmoid_w_momentum, criterion, optimizer, train_loader, epochs=20, model_save_path=sigmoid_w_momentum_save_path)
    
    sigmoid_w_momentum_training_loss_save_path = os.path.join(result_sigmoid_w_momentum_folder, 'model_mom=' + str(int(10*mom)))
    plot_training_losses(sigmoid_w_momentum_training_loss,sigmoid_w_momentum_training_loss_save_path)
# Out:
# sigmoid with momentum - 0.5
#
# results/first architecture/sigmoid_w_momentum/model_mom=5.pth
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv2d: 1-1                            [-1, 64, 32, 32]          1,792
# ├─BatchNorm2d: 1-2                       [-1, 64, 32, 32]          128
# ├─Sigmoid: 1-3                           [-1, 64, 32, 32]          --
# ├─MaxPool2d: 1-4                         [-1, 64, 16, 16]          --
# ├─Conv2d: 1-5                            [-1, 128, 16, 16]         73,856
# ├─BatchNorm2d: 1-6                       [-1, 128, 16, 16]         256
# ├─Sigmoid: 1-7                           [-1, 128, 16, 16]         --
# ├─MaxPool2d: 1-8                         [-1, 128, 8, 8]           --
# ├─Flatten: 1-9                           [-1, 8192]                --
# ├─Linear: 1-10                           [-1, 1024]                8,389,632
# ├─BatchNorm1d: 1-11                      [-1, 1024]                2,048
# ├─Sigmoid: 1-12                          [-1, 1024]                --
# ├─Linear: 1-13                           [-1, 10]                  10,250
# ├─Softmax: 1-14                          [-1, 10]                  --
# ==========================================================================================
# Total params: 8,477,962
# Trainable params: 8,477,962
# Non-trainable params: 0
# Total mult-adds (M): 29.04
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.52
# Params size (MB): 32.34
# Estimated Total Size (MB): 33.87
# ==========================================================================================
# Epoch 1/20, Loss: 2.270258445873895
# Epoch 2/20, Loss: 2.2270867797114966
# Epoch 3/20, Loss: 2.1966172633573526
# Epoch 4/20, Loss: 2.1745558117356754
# Epoch 5/20, Loss: 2.157225743888894
# Epoch 6/20, Loss: 2.140889573585042
# Epoch 7/20, Loss: 2.1264182838332624
# Epoch 8/20, Loss: 2.1137896936262965
# Epoch 9/20, Loss: 2.100170015069225
# Epoch 10/20, Loss: 2.0878943390858447
# Epoch 11/20, Loss: 2.0759175954877263
# Epoch 12/20, Loss: 2.065263124987902
# Epoch 13/20, Loss: 2.0549020323607015
# Epoch 14/20, Loss: 2.0450925308725107
# Epoch 15/20, Loss: 2.0349627600606444
# Epoch 16/20, Loss: 2.0255147308644736
# Epoch 17/20, Loss: 2.0169696301755393
# Epoch 18/20, Loss: 2.008341468508591
# Epoch 19/20, Loss: 1.9999913893392325
# Epoch 20/20, Loss: 1.9924731079269857
# Training Time: 0:06:09.242108 seconds
# Model parameters saved to: results/first architecture/sigmoid_w_momentum/model_mom=5.pth
# Plot saved to: results/first architecture/sigmoid_w_momentum/model_mom=5
# sigmoid with momentum - 0.7
#
# results/first architecture/sigmoid_w_momentum/model_mom=7.pth
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv2d: 1-1                            [-1, 64, 32, 32]          1,792
# ├─BatchNorm2d: 1-2                       [-1, 64, 32, 32]          128
# ├─Sigmoid: 1-3                           [-1, 64, 32, 32]          --
# ├─MaxPool2d: 1-4                         [-1, 64, 16, 16]          --
# ├─Conv2d: 1-5                            [-1, 128, 16, 16]         73,856
# ├─BatchNorm2d: 1-6                       [-1, 128, 16, 16]         256
# ├─Sigmoid: 1-7                           [-1, 128, 16, 16]         --
# ├─MaxPool2d: 1-8                         [-1, 128, 8, 8]           --
# ├─Flatten: 1-9                           [-1, 8192]                --
# ├─Linear: 1-10                           [-1, 1024]                8,389,632
# ├─BatchNorm1d: 1-11                      [-1, 1024]                2,048
# ├─Sigmoid: 1-12                          [-1, 1024]                --
# ├─Linear: 1-13                           [-1, 10]                  10,250
# ├─Softmax: 1-14                          [-1, 10]                  --
# ==========================================================================================
# Total params: 8,477,962
# Trainable params: 8,477,962
# Non-trainable params: 0
# Total mult-adds (M): 29.04
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.52
# Params size (MB): 32.34
# Estimated Total Size (MB): 33.87
# ==========================================================================================
# Epoch 1/20, Loss: 2.2583685771888478
# Epoch 2/20, Loss: 2.197694103126331
# Epoch 3/20, Loss: 2.161862808115342
# Epoch 4/20, Loss: 2.131229790885125
# Epoch 5/20, Loss: 2.1072248853076143
# Epoch 6/20, Loss: 2.0879737297287377
# Epoch 7/20, Loss: 2.0730556150531525
# Epoch 8/20, Loss: 2.0585423061609878
# Epoch 9/20, Loss: 2.044748664207166
# Epoch 10/20, Loss: 2.030951826163875
# Epoch 11/20, Loss: 2.0174413952985994
# Epoch 12/20, Loss: 2.0040174603767102
# Epoch 13/20, Loss: 1.991761749815148
# Epoch 14/20, Loss: 1.9803301301758613
# Epoch 15/20, Loss: 1.9704091244036583
# Epoch 16/20, Loss: 1.96100312196995
# Epoch 17/20, Loss: 1.9518115938167133
# Epoch 18/20, Loss: 1.9444324104377375
# Epoch 19/20, Loss: 1.9363515389240002
# Epoch 20/20, Loss: 1.9291542163285453
# Training Time: 0:06:19.188466 seconds
# Model parameters saved to: results/first architecture/sigmoid_w_momentum/model_mom=7.pth
# Plot saved to: results/first architecture/sigmoid_w_momentum/model_mom=7
# sigmoid with momentum - 0.9
#
# results/first architecture/sigmoid_w_momentum/model_mom=9.pth
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv2d: 1-1                            [-1, 64, 32, 32]          1,792
# ├─BatchNorm2d: 1-2                       [-1, 64, 32, 32]          128
# ├─Sigmoid: 1-3                           [-1, 64, 32, 32]          --
# ├─MaxPool2d: 1-4                         [-1, 64, 16, 16]          --
# ├─Conv2d: 1-5                            [-1, 128, 16, 16]         73,856
# ├─BatchNorm2d: 1-6                       [-1, 128, 16, 16]         256
# ├─Sigmoid: 1-7                           [-1, 128, 16, 16]         --
# ├─MaxPool2d: 1-8                         [-1, 128, 8, 8]           --
# ├─Flatten: 1-9                           [-1, 8192]                --
# ├─Linear: 1-10                           [-1, 1024]                8,389,632
# ├─BatchNorm1d: 1-11                      [-1, 1024]                2,048
# ├─Sigmoid: 1-12                          [-1, 1024]                --
# ├─Linear: 1-13                           [-1, 10]                  10,250
# ├─Softmax: 1-14                          [-1, 10]                  --
# ==========================================================================================
# Total params: 8,477,962
# Trainable params: 8,477,962
# Non-trainable params: 0
# Total mult-adds (M): 29.04
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.52
# Params size (MB): 32.34
# Estimated Total Size (MB): 33.87
# ==========================================================================================
# Epoch 1/20, Loss: 2.204748764977126
# Epoch 2/20, Loss: 2.1072806943103175
# Epoch 3/20, Loss: 2.062290495466393
# Epoch 4/20, Loss: 2.026649819005786
# Epoch 5/20, Loss: 1.9934617384620335
# Epoch 6/20, Loss: 1.9650000963369598
# Epoch 7/20, Loss: 1.9399962975545917
# Epoch 8/20, Loss: 1.9219497585540537
# Epoch 9/20, Loss: 1.9068521351155723
# Epoch 10/20, Loss: 1.8935842408853418
# Epoch 11/20, Loss: 1.8833079937169008
# Epoch 12/20, Loss: 1.8733427096205904
# Epoch 13/20, Loss: 1.865585703679058
# Epoch 14/20, Loss: 1.8596950810583657
# Epoch 15/20, Loss: 1.8518404594772613
# Epoch 16/20, Loss: 1.8477686764029286
# Epoch 17/20, Loss: 1.8417844417150064
# Epoch 18/20, Loss: 1.8357450305043583
# Epoch 19/20, Loss: 1.832332792489425
# Epoch 20/20, Loss: 1.8276055743322348
# Training Time: 0:06:26.446934 seconds
# Model parameters saved to: results/first architecture/sigmoid_w_momentum/model_mom=9.pth
# Plot saved to: results/first architecture/sigmoid_w_momentum/model_mom=9

# %% [markdown]
# evaluate the trained models

# %%
for mom in sigmoid_mom_arr:
    print('sigmoid with momentum - '+str(mom))
    sigmoid_w_momentum_save_path = os.path.join(result_sigmoid_w_momentum_folder, 'model_mom=' + str(int(10*mom)) +'.pth')
    print('model loaded from- '+sigmoid_w_momentum_save_path)
    loaded_sigmoid_w_momentum_model = load_model(sigmoid_w_momentum, sigmoid_w_momentum_save_path)
    loaded_sigmoid_w_momentum_model = loaded_sigmoid_w_momentum_model.to(device)
    evaluate_model(loaded_sigmoid_w_momentum_model,test_loader)
    print('\n')
# Out:
# sigmoid with momentum - 0.5
# model loaded from- results/first architecture/sigmoid_w_momentum/model_mom=5.pth
# Test Accuracy: 0.5185
#
#
# sigmoid with momentum - 0.7
# model loaded from- results/first architecture/sigmoid_w_momentum/model_mom=7.pth
# Test Accuracy: 0.5701
#
#
# sigmoid with momentum - 0.9
# model loaded from- results/first architecture/sigmoid_w_momentum/model_mom=9.pth
# Test Accuracy: 0.5842

# %% [markdown]
# #### 3. Sigmoid with Adam

# %%
sigmoid_w_adam = CNN(nn.Sigmoid()).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(sigmoid_w_adam.parameters(),lr=0.001)

result_sigmoid_w_adam_folder = "results/first architecture/sigmoid_w_adam"
os.makedirs(result_sigmoid_w_adam_folder, exist_ok=True)
sigmoid_w_adam_save_path = os.path.join(result_sigmoid_w_adam_folder, 'model.pth')

sigmoid_w_adam_losses = train_model(sigmoid_w_adam, criterion, optimizer, train_loader, epochs=20,model_save_path=sigmoid_w_adam_save_path)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#            Sigmoid-3           [-1, 64, 32, 32]               0
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#        BatchNorm2d-6          [-1, 128, 16, 16]             256
#            Sigmoid-7          [-1, 128, 16, 16]               0
#          MaxPool2d-8            [-1, 128, 8, 8]               0
#            Flatten-9                 [-1, 8192]               0
#            Linear-10                 [-1, 1024]       8,389,632
#       BatchNorm1d-11                 [-1, 1024]           2,048
#           Sigmoid-12                 [-1, 1024]               0
#            Linear-13                   [-1, 10]          10,250
#           Softmax-14                   [-1, 10]               0
# ================================================================
# Total params: 8,477,962
# Trainable params: 8,477,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 2.52
# Params size (MB): 32.34
# Estimated Total Size (MB): 34.88
# ----------------------------------------------------------------
# Epoch 1/20, Loss: 2.015840454936942
# Epoch 2/20, Loss: 1.9147041388179944
# Epoch 3/20, Loss: 1.8408802997730578
# Epoch 4/20, Loss: 1.7986767261534395
# Epoch 5/20, Loss: 1.775338395172373
# Epoch 6/20, Loss: 1.759501773530565
# Epoch 7/20, Loss: 1.74314274568387
# Epoch 8/20, Loss: 1.7278328765078883
# Epoch 9/20, Loss: 1.7159402065569787
# Epoch 10/20, Loss: 1.701505529606129
# Epoch 11/20, Loss: 1.6876177676498432
# Epoch 12/20, Loss: 1.676936134810338
# Epoch 13/20, Loss: 1.665987028490247
# Epoch 14/20, Loss: 1.6592855788862613
# Epoch 15/20, Loss: 1.6455898740712334
# Epoch 16/20, Loss: 1.6353730422151669
# Epoch 17/20, Loss: 1.6280121381020607
# Epoch 18/20, Loss: 1.617569072472165
# Epoch 19/20, Loss: 1.609310101212748
# Epoch 20/20, Loss: 1.601969110996217
# Training Time: 0:10:28.861910 seconds
# Model parameters saved to: results/first architecture/sigmoid_w_adam/model.pth

# %%
sigmoid_w_adam_training_losses_save_path = os.path.join(result_sigmoid_w_adam_folder, 'training_losses_plot')
plot_training_losses(sigmoid_w_adam_losses,sigmoid_w_adam_training_losses_save_path)
# Out:
# Plot saved to: results/first architecture/sigmoid_w_adam/training_losses_plot

# %%
loaded_sigmoid_w_adam_model = load_model(sigmoid_w_adam, sigmoid_w_adam_save_path)
loaded_sigmoid_w_adam_model = loaded_sigmoid_w_adam_model.to(device)
evaluate_model(loaded_sigmoid_w_adam_model,test_loader)
# Out:
# Test Accuracy: 0.6889
