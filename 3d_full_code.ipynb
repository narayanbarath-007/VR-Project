# %%
# !pip install matplotlib filterpy lap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: filterpy in /home/barath/.local/lib/python3.10/site-packages (1.4.5)
# Requirement already satisfied: lap in /home/barath/.local/lib/python3.10/site-packages (0.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/barath/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/barath/.local/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/barath/.local/lib/python3.10/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: numpy>=1.20 in /home/barath/.local/lib/python3.10/site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from filterpy) (1.10.1)
# Requirement already satisfied: six>=1.5 in /home/barath/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.12.0)

# %%
import os
import cv2
import sys
import numpy as np
from ultralytics import YOLO
import torch
import torchvision
import random
from deep_sort_realtime.deepsort_tracker import DeepSort
torch.backends.cudnn.enabled = True  # Enable cuDNN
torch.backends.cudnn.benchmark = True  # Use cuDNN's auto-tuner for the best performance
from sort.sort import *
# from deep_sort.deep_sort.tracker import Tracker
# from deep_sort.tools import generate_detections as gdet
# from deep_sort.deep_sort import nn_matching
# from deep_sort.deep_sort.detection import Detection

# %%
# device = torch.device("cpu")
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# results = model.track(source="./darknet/Video1.MP4", show=True)  # Tracking with default tracker

# %% [markdown]
# SORT tracker with FasterRCNN detection

# %%
def tracker_sort_rcnn(input_path,output_path):
    video_path = input_path
    video_out_path = output_path 
    # os.path.join('.','out1.mp4')

    cap = cv2.VideoCapture(video_path)
    ret, frame = cap.read()

    cap_out = cv2.VideoWriter(video_out_path, cv2.VideoWriter_fourcc(*'MP4V'), cap.get(cv2.CAP_PROP_FPS),
                            (frame.shape[1], frame.shape[0]))

    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True).to(device)
    model.eval()
    tracker = Sort(iou_threshold=0.2,max_age=600)

    # colors = [(random.randint(0, 255), random.randint(0, 255), random.randint(0, 255)) for j in range(10)]

    detection_threshold = 0.97
    RED = (255,0,0)
    WHITE = (255, 255, 255)
    track_ids = []
    count = 0
    temp = 0
    bounding_boxes_ids = np.array([])
    while ret:
        transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor()])
        frame_transformed = transform(frame).to(device)
        with torch.no_grad():
#       pred = model([img])
            results = model([frame_transformed])[0]
        detections = []
        for i in range(len(results["scores"])):
            confidence = results["scores"][i]
            if float(confidence) < detection_threshold:
                continue
            xmin, ymin, xmax, ymax = int(results["boxes"][i][0]), int(results["boxes"][i][1]), int(results["boxes"][i][2]), int(results["boxes"][i][3])
            class_id = int(results["labels"][i])
            if class_id not in [3]:
                continue
            # add the bounding box (x, y, w, h), confidence and class id to the results list
            detections.append([xmin, ymin, xmax, ymax])

        if(len(detections) != 0):
            detections = np.array(detections)
            detections = detections.reshape([detections.shape[0], 4])
            tracks = tracker.update(detections)

            for i in range(tracks.shape[0]):
                bounding_boxes_ids = np.append(bounding_boxes_ids, np.array([tracks[i][4]]))

            count = np.unique(bounding_boxes_ids).shape[0]
            temp = count
            # detections = np.array(detections)
            for i in range(detections.shape[0]):
                cv2.rectangle(frame, (int(detections[i][0]), int(detections[i][1])), (int(detections[i][2]), int(detections[i][3])), (0, 255, 0), 2)
                cv2.putText(frame, "Car", (int(detections[i][0])-10, int(detections[i][1])-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
        else:
            count = temp
        cv2.putText(frame, f'Count: {int(count)}', (20, 100), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0), 2)
        cap_out.write(frame)
        ret, frame = cap.read()
    print(count)
    cap.release()
    cap_out.release()
    cv2.destroyAllWindows()

# %% [markdown]
# SORT tracker with YOLOV5 detection

# %%
def tracker_sort_yolo(input_path,output_path):
    video_path = input_path
    video_out_path = output_path 
    # os.path.join('.','out1.mp4')

    cap = cv2.VideoCapture(video_path)
    ret, frame = cap.read()

    cap_out = cv2.VideoWriter(video_out_path, cv2.VideoWriter_fourcc(*'MP4V'), cap.get(cv2.CAP_PROP_FPS),
                            (frame.shape[1], frame.shape[0]))

    model = YOLO("yolov5l.pt")
    # metric = nn_matching.NearestNeighborDistanceMetric("cosine",0.3,None)
    # tracker = Tracker(metric)
    tracker = Sort(iou_threshold=0.2,max_age=600)

    # colors = [(random.randint(0, 255), random.randint(0, 255), random.randint(0, 255)) for j in range(10)]

    detection_threshold = 0.75
    RED = (255,0,0)
    WHITE = (255, 255, 255)
    track_ids = []
    count = 0
    temp = 0
    bounding_boxes_ids = np.array([])
    while ret:
        results = model.predict(frame)[0]
        detections = []
        for result in results.boxes.data.tolist():
            confidence = result[4]
            if float(confidence) < detection_threshold:
                continue
            xmin, ymin, xmax, ymax = int(result[0]), int(result[1]), int(result[2]), int(result[3])
            class_id = int(result[5])
            if class_id not in [2]:
                continue
            # add the bounding box (x, y, w, h), confidence and class id to the results list
            detections.append([xmin, ymin, xmax , ymax])

        if(len(detections) != 0):
            detections = np.array(detections)
            detections = detections.reshape([detections.shape[0], 4])
            tracks = tracker.update(detections)

            for i in range(tracks.shape[0]):
                bounding_boxes_ids = np.append(bounding_boxes_ids, np.array([tracks[i][4]]))

            count = np.unique(bounding_boxes_ids).shape[0]
            temp = count
            # detections = np.array(detections)
            for i in range(detections.shape[0]):
                cv2.rectangle(frame, (int(detections[i][0]), int(detections[i][1])), (int(detections[i][2]), int(detections[i][3])), (0, 255, 0), 2)
                cv2.putText(frame, "Car", (int(detections[i][0])-10, int(detections[i][1])-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
        else:
            count = temp
        cv2.putText(frame, f'Count: {int(count)}', (20, 100), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0), 2)
        cap_out.write(frame)
        ret, frame = cap.read()
    print(count)
    cap.release()
    cap_out.release()
    cv2.destroyAllWindows()

# %% [markdown]
# Deepsort Tracker with YOLOV5 detector

# %%
def tracker_deepsort_yolo(input_path,output_path):
    video_path = input_path
    video_out_path = output_path 
    # os.path.join('.','out1.mp4')

    cap = cv2.VideoCapture(video_path)
    ret, frame = cap.read()

    cap_out = cv2.VideoWriter(video_out_path, cv2.VideoWriter_fourcc(*'MP4V'), 25,
                            (frame.shape[1], frame.shape[0]))

    model = YOLO("yolov5l.pt")
    # metric = nn_matching.NearestNeighborDistanceMetric("cosine",0.3,None)
    # tracker = Tracker(metric)
    tracker = DeepSort(max_age=25,nms_max_overlap = 0.3)

    # colors = [(random.randint(0, 255), random.randint(0, 255), random.randint(0, 255)) for j in range(10)]

    detection_threshold = 0.81
    RED = (255,0,0)
    WHITE = (255, 255, 255)
    track_ids = []
    count = 0
    while ret:
        results = model.predict(frame)[0]
        detections = []
        for result in results.boxes.data.tolist():
            confidence = result[4]
            if float(confidence) < detection_threshold:
                continue
            xmin, ymin, xmax, ymax = int(result[0]), int(result[1]), int(result[2]), int(result[3])
            class_id = int(result[5])
            if class_id not in [2]:
                continue
            # add the bounding box (x, y, w, h), confidence and class id to the results list
            detections.append([[xmin, ymin, xmax - xmin, ymax - ymin], confidence, class_id])
            
        tracks = tracker.update_tracks(detections, frame=frame)

        for track in tracks:
            if not track.is_confirmed():
                continue
            track_id = track.track_id
            if(track_id not in track_ids):
                count += 1
                track_ids.append(track_id)
            ltrb = track.to_ltrb()
            # print(ltrb)
            x1,y1,x2,y2 = int(ltrb[0]),int(ltrb[1]),int(ltrb[2]),int(ltrb[3])
            cv2.rectangle(frame, (x1, y1), (x2,y2), RED, 2)
            cv2.putText(frame, str(track_id), (xmin + 5, ymin - 8),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, WHITE, 2)
        cv2.putText(frame, f'Count: {int(count)}', (20, 100), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0), 2)
        cap_out.write(frame)
        ret, frame = cap.read()
    print(count)
    cap.release()
    cap_out.release()
    cv2.destroyAllWindows()

# %% [markdown]
# Deepsort tracker with FasterRCNN detector

# %%
def tracker_deepsort_rcnn(input_path,output_path):
    video_path = input_path
    video_out_path = output_path 
    # os.path.join('.','out1.mp4')

    cap = cv2.VideoCapture(video_path)
    ret, frame = cap.read()

    cap_out = cv2.VideoWriter(video_out_path, cv2.VideoWriter_fourcc(*'MP4V'), cap.get(cv2.CAP_PROP_FPS),
                            (frame.shape[1], frame.shape[0]))

    # model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT)
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True).to(device)
    model.eval()
    # metric = nn_matching.NearestNeighborDistanceMetric("cosine",0.3,None)
    # tracker = Tracker(metric)
    tracker = DeepSort(max_iou_distance=0.3,max_age=20)

    # colors = [(random.randint(0, 255), random.randint(0, 255), random.randint(0, 255)) for j in range(10)]

    detection_threshold = 0.993
    RED = (255,0,0)
    WHITE = (255, 255, 255)
    track_ids = []
    count = 0
    while ret:
        transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor()])
        frame_transformed = transform(frame).to(device)
        with torch.no_grad():
#       pred = model([img])
            results = model([frame_transformed])[0]
        # print(results)
        detections = []
        for i in range(len(results["scores"])):
            confidence = results["scores"][i]
            if float(confidence) < detection_threshold:
                continue
            xmin, ymin, xmax, ymax = int(results["boxes"][i][0]), int(results["boxes"][i][1]), int(results["boxes"][i][2]), int(results["boxes"][i][3])
            class_id = int(results["labels"][i])
            if class_id not in [3]:
                continue
            # add the bounding box (x, y, w, h), confidence and class id to the results list
            detections.append([[xmin, ymin, xmax - xmin, ymax - ymin], confidence, class_id])

        tracks = tracker.update_tracks(detections, frame=frame)

        for track in tracks:
            if not track.is_confirmed():
                continue
            track_id = track.track_id
            if(track_id not in track_ids):
                count += 1
                track_ids.append(track_id)
            ltrb = track.to_ltrb()
            # print(ltrb)
            x1,y1,x2,y2 = int(ltrb[0]),int(ltrb[1]),int(ltrb[2]),int(ltrb[3])
            cv2.rectangle(frame, (x1, y1), (x2,y2), RED, 2)
            cv2.putText(frame, str(track_id), (xmin + 5, ymin - 8),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, WHITE, 2)
        # count = tracker.tracker._next_id-1
        cv2.putText(frame, f'Count: {int(count)}', (20, 100), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0), 2)
        cap_out.write(frame)
        ret, frame = cap.read()
    print(count)
    cap.release()
    cap_out.release()
    cv2.destroyAllWindows()

# %%
input_path = os.path.join('.','Original.mp4')
output_path1 = os.path.join('.','out1.mp4')
output_path2 = os.path.join('.','out2.mp4')
output_path3 = os.path.join('.','out3.mp4')
output_path4 = os.path.join('.','out4.mp4')

# %%
tracker_deepsort_yolo(input_path,output_path1)

# %%
tracker_deepsort_rcnn(input_path,output_path2)

# %%
tracker_sort_yolo(input_path,output_path3)
# Out:
# PRO TIP 💡 Replace 'model=yolov5l.pt' with new 'model=yolov5lu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 0: 384x640 8 persons, 1 bicycle, 8 cars, 6 motorcycles, 1 bus, 2 trucks, 2 backpacks, 43.0ms
# Speed: 1.7ms preprocess, 43.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 cars, 6 motorcycles, 1 bus, 2 trucks, 1 backpack, 42.4ms
# Speed: 2.6ms preprocess, 42.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 cars, 6 motorcycles, 1 bus, 2 trucks, 42.4ms
# Speed: 2.5ms preprocess, 42.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 cars, 6 motorcycles, 3 trucks, 42.3ms
# Speed: 3.3ms preprocess, 42.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 cars, 5 motorcycles, 3 trucks, 38.4ms
# Speed: 2.2ms preprocess, 38.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 9 cars, 5 motorcycles, 3 trucks, 38.1ms
# Speed: 2.9ms preprocess, 38.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 8 cars, 5 motorcycles, 2 trucks, 37.9ms
# Speed: 2.9ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 8 cars, 6 motorcycles, 1 bus, 2 trucks, 37.9ms
# Speed: 2.3ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 10 cars, 7 motorcycles, 2 trucks, 37.8ms
# Speed: 1.9ms preprocess, 37.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 9 cars, 6 motorcycles, 3 trucks, 37.9ms
# Speed: 3.4ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 cars, 7 motorcycles, 2 trucks, 37.9ms
# Speed: 2.8ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 10 cars, 7 motorcycles, 1 bus, 4 trucks, 38.0ms
# Speed: 2.4ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 9 cars, 8 motorcycles, 6 trucks, 38.2ms
# Speed: 3.4ms preprocess, 38.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 13 cars, 6 motorcycles, 5 trucks, 38.1ms
# Speed: 2.7ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 10 cars, 7 motorcycles, 5 trucks, 38.0ms
# Speed: 2.2ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 10 cars, 6 motorcycles, 2 trucks, 38.0ms
# Speed: 2.5ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 cars, 7 motorcycles, 1 bus, 1 truck, 38.0ms
# Speed: 2.3ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 7 cars, 6 motorcycles, 2 trucks, 38.0ms
# Speed: 2.9ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 cars, 7 motorcycles, 2 trucks, 38.3ms
# Speed: 2.8ms preprocess, 38.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 bicycle, 6 cars, 5 motorcycles, 3 trucks, 38.0ms
# Speed: 2.9ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 6 cars, 5 motorcycles, 4 trucks, 38.0ms
# Speed: 2.2ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 7 cars, 5 motorcycles, 4 trucks, 38.0ms
# Speed: 2.1ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 7 cars, 7 motorcycles, 2 trucks, 38.1ms
# Speed: 2.6ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 bicycle, 6 cars, 7 motorcycles, 5 trucks, 38.1ms
# Speed: 3.3ms preprocess, 38.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 bicycle, 5 cars, 6 motorcycles, 1 bus, 5 trucks, 38.0ms
# Speed: 4.0ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 5 cars, 6 motorcycles, 4 trucks, 38.1ms
# Speed: 2.6ms preprocess, 38.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 bicycle, 6 cars, 6 motorcycles, 5 trucks, 38.5ms
# Speed: 2.5ms preprocess, 38.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 7 cars, 6 motorcycles, 5 trucks, 37.9ms
# Speed: 3.0ms preprocess, 37.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 7 cars, 5 motorcycles, 4 trucks, 38.0ms
# Speed: 2.7ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 8 cars, 6 motorcycles, 1 bus, 5 trucks, 38.0ms
# Speed: 2.1ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 bicycle, 11 cars, 6 motorcycles, 4 trucks, 37.9ms
# Speed: 1.8ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 bicycles, 8 cars, 6 motorcycles, 3 trucks, 37.9ms
# Speed: 1.8ms preprocess, 37.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 7 cars, 5 motorcycles, 4 trucks, 38.1ms
# Speed: 2.2ms preprocess, 38.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 bicycle, 7 cars, 7 motorcycles, 3 trucks, 38.1ms
# Speed: 2.6ms preprocess, 38.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 bicycles, 6 cars, 6 motorcycles, 3 trucks, 38.0ms
# Speed: 2.6ms preprocess, 38.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 bicycles, 6 cars, 6 motorcycles, 3 trucks, 38.1ms
# Speed: 3.7ms preprocess, 38.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 bicycles, 5 cars, 4 motorcycles, 3 trucks, 37.9ms
# Speed: 4.3ms preprocess, 37.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 bicycles, 6 cars, 7 motorcycles, 4 trucks, 38.0ms
# Speed: 2.7ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 2 bicycles, 8 cars, 7 motorcycles, 3 trucks, 38.0ms
# Speed: 3.0ms preprocess, 38.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 bicycles, 8 cars, 7 motorcycles, 4 trucks, 37.9ms
# Speed: 3.9ms preprocess, 37.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 bicycles, 6 cars, 6 motorcycles, 3 trucks, 38.3ms
# Speed: 2.7ms preprocess, 38.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 bicycles, 8 cars, 5 motorcycles, 3 trucks, 37.9ms
# Speed: 2.9ms preprocess, 37.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 bicycles, 5 cars, 5 motorcycles, 2 trucks, 37.8ms
# Speed: 5.6ms preprocess, 37.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 bicycles, 8 cars, 6 motorcycles, 2 trucks, 38.0ms
# Speed: 2.5ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 2 bicycles, 8 cars, 5 motorcycles, 1 truck, 38.0ms
# Speed: 1.9ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 bicycles, 6 cars, 5 motorcycles, 2 trucks, 38.0ms
# Speed: 1.8ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 bicycles, 8 cars, 5 motorcycles, 1 truck, 37.9ms
# Speed: 2.0ms preprocess, 37.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 3 bicycles, 6 cars, 5 motorcycles, 1 truck, 38.4ms
# Speed: 2.1ms preprocess, 38.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 bicycles, 6 cars, 5 motorcycles, 1 truck, 38.0ms
# Speed: 3.0ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 bicycles, 5 cars, 4 motorcycles, 1 truck, 38.0ms
# Speed: 2.2ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 bicycles, 9 cars, 3 motorcycles, 1 truck, 37.9ms
# Speed: 1.9ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 bicycles, 7 cars, 4 motorcycles, 2 trucks, 38.0ms
# Speed: 1.9ms preprocess, 38.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 bicycles, 8 cars, 3 motorcycles, 1 truck, 1 traffic light, 38.2ms
# Speed: 6.4ms preprocess, 38.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 bicycles, 8 cars, 3 motorcycles, 1 truck, 38.0ms
# Speed: 4.6ms preprocess, 38.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 8 cars, 4 motorcycles, 1 truck, 38.3ms
# Speed: 2.1ms preprocess, 38.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 10 cars, 2 motorcycles, 1 bus, 3 trucks, 38.0ms
# Speed: 3.1ms preprocess, 38.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 bicycle, 7 cars, 3 motorcycles, 2 trucks, 38.0ms
# Speed: 2.5ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 9 cars, 3 motorcycles, 3 trucks, 38.4ms
# Speed: 2.5ms preprocess, 38.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 9 cars, 3 motorcycles, 4 trucks, 38.0ms
# Speed: 2.8ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 bicycle, 9 cars, 3 motorcycles, 4 trucks, 38.0ms
# Speed: 2.1ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 10 cars, 2 motorcycles, 2 trucks, 38.0ms
# Speed: 2.8ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 8 cars, 2 motorcycles, 4 trucks, 38.0ms
# Speed: 2.7ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 7 cars, 2 motorcycles, 4 trucks, 38.1ms
# Speed: 1.8ms preprocess, 38.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bicycles, 10 cars, 2 motorcycles, 2 trucks, 38.1ms
# Speed: 2.9ms preprocess, 38.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bicycles, 7 cars, 2 motorcycles, 3 trucks, 1 traffic light, 37.9ms
# Speed: 2.2ms preprocess, 37.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bicycles, 11 cars, 2 motorcycles, 2 trucks, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bicycles, 9 cars, 2 motorcycles, 3 trucks, 38.1ms
# Speed: 2.7ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bicycles, 7 cars, 3 motorcycles, 3 trucks, 38.0ms
# Speed: 2.8ms preprocess, 38.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 bicycles, 7 cars, 3 motorcycles, 3 trucks, 38.1ms
# Speed: 2.9ms preprocess, 38.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 bicycles, 7 cars, 4 motorcycles, 2 trucks, 38.0ms
# Speed: 3.4ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 bicycles, 8 cars, 4 motorcycles, 2 trucks, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 bicycles, 6 cars, 5 motorcycles, 1 truck, 1 backpack, 38.5ms
# Speed: 2.0ms preprocess, 38.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 bicycles, 7 cars, 4 motorcycles, 1 truck, 38.1ms
# Speed: 3.0ms preprocess, 38.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 bicycles, 8 cars, 3 motorcycles, 2 trucks, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 bicycles, 7 cars, 3 motorcycles, 2 trucks, 38.0ms
# Speed: 1.8ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 bicycles, 6 cars, 3 motorcycles, 1 truck, 1 backpack, 37.9ms
# Speed: 2.8ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 bicycles, 6 cars, 3 motorcycles, 1 truck, 1 backpack, 37.9ms
# Speed: 1.7ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bicycles, 7 cars, 4 motorcycles, 1 truck, 1 backpack, 38.1ms
# Speed: 2.2ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 bicycles, 6 cars, 3 motorcycles, 2 trucks, 1 backpack, 37.9ms
# Speed: 3.0ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 bicycles, 6 cars, 3 motorcycles, 2 trucks, 1 backpack, 38.3ms
# Speed: 2.1ms preprocess, 38.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 bicycles, 7 cars, 2 motorcycles, 3 trucks, 1 backpack, 38.4ms
# Speed: 4.2ms preprocess, 38.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bicycles, 6 cars, 2 motorcycles, 2 trucks, 2 backpacks, 37.9ms
# Speed: 2.4ms preprocess, 37.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 bicycles, 7 cars, 2 motorcycles, 2 trucks, 2 backpacks, 38.1ms
# Speed: 2.5ms preprocess, 38.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bicycles, 7 cars, 2 motorcycles, 1 truck, 3 backpacks, 37.9ms
# Speed: 1.8ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bicycles, 7 cars, 2 motorcycles, 1 truck, 3 backpacks, 38.1ms
# Speed: 2.7ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 bicycles, 8 cars, 2 motorcycles, 1 truck, 2 backpacks, 38.2ms
# Speed: 2.2ms preprocess, 38.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 bicycles, 10 cars, 3 motorcycles, 1 truck, 2 backpacks, 38.1ms
# Speed: 4.1ms preprocess, 38.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bicycles, 9 cars, 3 motorcycles, 1 truck, 1 backpack, 38.1ms
# Speed: 4.3ms preprocess, 38.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bicycles, 9 cars, 3 motorcycles, 1 truck, 1 backpack, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bicycles, 8 cars, 4 motorcycles, 2 trucks, 1 backpack, 37.9ms
# Speed: 1.8ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bicycles, 6 cars, 3 motorcycles, 1 truck, 1 backpack, 38.2ms
# Speed: 3.1ms preprocess, 38.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 2 bicycles, 9 cars, 3 motorcycles, 1 truck, 3 backpacks, 38.3ms
# Speed: 2.9ms preprocess, 38.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bicycles, 9 cars, 4 motorcycles, 2 trucks, 1 backpack, 38.1ms
# Speed: 2.7ms preprocess, 38.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bicycles, 9 cars, 4 motorcycles, 1 truck, 1 backpack, 38.0ms
# Speed: 3.0ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bicycles, 9 cars, 4 motorcycles, 1 truck, 2 backpacks, 37.9ms
# Speed: 1.9ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bicycles, 8 cars, 4 motorcycles, 1 truck, 1 backpack, 38.1ms
# Speed: 3.3ms preprocess, 38.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bicycles, 8 cars, 2 motorcycles, 1 truck, 2 backpacks, 37.9ms
# Speed: 2.3ms preprocess, 37.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 8 cars, 2 motorcycles, 1 truck, 2 backpacks, 37.9ms
# Speed: 1.8ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 5 cars, 3 motorcycles, 2 trucks, 1 backpack, 38.2ms
# Speed: 3.8ms preprocess, 38.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 8 cars, 2 motorcycles, 2 trucks, 2 backpacks, 38.0ms
# Speed: 2.1ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 8 cars, 3 motorcycles, 2 trucks, 2 backpacks, 38.0ms
# Speed: 1.8ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 bicycles, 6 cars, 2 motorcycles, 2 trucks, 1 backpack, 38.2ms
# Speed: 3.4ms preprocess, 38.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 7 cars, 2 motorcycles, 2 trucks, 2 backpacks, 38.0ms
# Speed: 2.4ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 9 cars, 2 motorcycles, 2 trucks, 1 backpack, 38.1ms
# Speed: 2.3ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 8 cars, 2 motorcycles, 1 truck, 1 backpack, 38.1ms
# Speed: 3.0ms preprocess, 38.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 9 cars, 2 motorcycles, 1 truck, 2 backpacks, 43.0ms
# Speed: 2.9ms preprocess, 43.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 7 cars, 2 motorcycles, 1 truck, 1 backpack, 38.0ms
# Speed: 3.3ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 bicycle, 10 cars, 2 motorcycles, 2 trucks, 1 backpack, 38.2ms
# Speed: 2.7ms preprocess, 38.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 10 cars, 1 motorcycle, 1 truck, 38.0ms
# Speed: 2.9ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 7 cars, 2 motorcycles, 1 truck, 37.9ms
# Speed: 2.5ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 9 cars, 2 motorcycles, 1 truck, 38.2ms
# Speed: 2.3ms preprocess, 38.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 8 cars, 2 motorcycles, 1 truck, 38.1ms
# Speed: 3.1ms preprocess, 38.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 8 cars, 3 motorcycles, 1 truck, 38.1ms
# Speed: 2.3ms preprocess, 38.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 10 cars, 1 motorcycle, 1 truck, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 12 cars, 2 motorcycles, 1 truck, 37.9ms
# Speed: 2.2ms preprocess, 37.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 8 cars, 2 motorcycles, 2 trucks, 38.0ms
# Speed: 1.8ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 9 cars, 2 motorcycles, 3 trucks, 38.0ms
# Speed: 2.5ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 8 cars, 3 motorcycles, 2 trucks, 38.0ms
# Speed: 2.6ms preprocess, 38.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 7 cars, 4 motorcycles, 2 trucks, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 7 cars, 4 motorcycles, 2 trucks, 38.4ms
# Speed: 2.3ms preprocess, 38.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 8 cars, 4 motorcycles, 2 trucks, 38.1ms
# Speed: 3.0ms preprocess, 38.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 5 cars, 4 motorcycles, 2 trucks, 38.0ms
# Speed: 2.1ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 7 cars, 4 motorcycles, 2 trucks, 38.0ms
# Speed: 1.8ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 6 cars, 4 motorcycles, 2 trucks, 38.2ms
# Speed: 3.0ms preprocess, 38.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 7 cars, 4 motorcycles, 4 trucks, 38.0ms
# Speed: 2.5ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 7 cars, 5 motorcycles, 3 trucks, 38.0ms
# Speed: 1.9ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 7 cars, 5 motorcycles, 4 trucks, 38.1ms
# Speed: 1.9ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 7 cars, 6 motorcycles, 2 trucks, 38.2ms
# Speed: 2.8ms preprocess, 38.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 6 cars, 5 motorcycles, 3 trucks, 37.9ms
# Speed: 2.6ms preprocess, 37.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 7 cars, 6 motorcycles, 1 truck, 38.1ms
# Speed: 3.7ms preprocess, 38.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 9 cars, 5 motorcycles, 2 trucks, 38.0ms
# Speed: 3.2ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 6 cars, 5 motorcycles, 1 truck, 38.1ms
# Speed: 3.0ms preprocess, 38.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 9 cars, 6 motorcycles, 2 trucks, 38.0ms
# Speed: 4.2ms preprocess, 38.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 bicycle, 6 cars, 4 motorcycles, 1 truck, 38.1ms
# Speed: 2.3ms preprocess, 38.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 7 cars, 5 motorcycles, 1 truck, 38.1ms
# Speed: 1.9ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 7 cars, 6 motorcycles, 1 truck, 38.1ms
# Speed: 3.5ms preprocess, 38.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 bicycles, 6 cars, 5 motorcycles, 1 truck, 38.0ms
# Speed: 2.4ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 5 motorcycles, 1 truck, 38.1ms
# Speed: 3.4ms preprocess, 38.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 cars, 5 motorcycles, 1 truck, 38.0ms
# Speed: 2.3ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 cars, 4 motorcycles, 1 truck, 38.0ms
# Speed: 2.8ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 4 motorcycles, 1 truck, 38.0ms
# Speed: 3.1ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 9 cars, 4 motorcycles, 1 truck, 37.9ms
# Speed: 2.2ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 cars, 5 motorcycles, 1 truck, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 cars, 6 motorcycles, 1 truck, 38.0ms
# Speed: 2.1ms preprocess, 38.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 9 cars, 7 motorcycles, 38.1ms
# Speed: 3.2ms preprocess, 38.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 cars, 5 motorcycles, 37.9ms
# Speed: 2.0ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 9 cars, 5 motorcycles, 38.2ms
# Speed: 2.2ms preprocess, 38.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 8 cars, 5 motorcycles, 38.1ms
# Speed: 3.3ms preprocess, 38.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 8 cars, 5 motorcycles, 1 truck, 37.9ms
# Speed: 2.1ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 cars, 6 motorcycles, 38.1ms
# Speed: 1.8ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 cars, 6 motorcycles, 38.1ms
# Speed: 2.7ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 9 cars, 6 motorcycles, 1 truck, 38.0ms
# Speed: 2.9ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 10 cars, 6 motorcycles, 1 truck, 38.0ms
# Speed: 3.2ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 10 cars, 4 motorcycles, 1 truck, 38.0ms
# Speed: 2.2ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 cars, 5 motorcycles, 2 trucks, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 cars, 4 motorcycles, 3 trucks, 38.2ms
# Speed: 2.4ms preprocess, 38.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 10 cars, 3 motorcycles, 3 trucks, 37.9ms
# Speed: 2.8ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 8 cars, 3 motorcycles, 2 trucks, 38.1ms
# Speed: 2.1ms preprocess, 38.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 cars, 3 motorcycles, 3 trucks, 38.1ms
# Speed: 3.0ms preprocess, 38.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 8 cars, 3 motorcycles, 2 trucks, 38.3ms
# Speed: 4.1ms preprocess, 38.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 8 cars, 3 motorcycles, 3 trucks, 38.1ms
# Speed: 4.0ms preprocess, 38.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 cars, 4 motorcycles, 3 trucks, 38.1ms
# Speed: 3.4ms preprocess, 38.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 6 cars, 5 motorcycles, 4 trucks, 38.1ms
# Speed: 2.4ms preprocess, 38.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 3 motorcycles, 4 trucks, 38.0ms
# Speed: 3.6ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 cars, 5 motorcycles, 3 trucks, 38.0ms
# Speed: 2.4ms preprocess, 38.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 4 motorcycles, 3 trucks, 38.0ms
# Speed: 1.9ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 5 motorcycles, 3 trucks, 38.3ms
# Speed: 3.4ms preprocess, 38.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 5 motorcycles, 2 trucks, 37.9ms
# Speed: 2.1ms preprocess, 37.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 8 cars, 5 motorcycles, 2 trucks, 38.4ms
# Speed: 2.4ms preprocess, 38.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 cars, 7 motorcycles, 3 trucks, 38.1ms
# Speed: 2.9ms preprocess, 38.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 6 motorcycles, 2 trucks, 38.0ms
# Speed: 3.2ms preprocess, 38.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 6 motorcycles, 2 trucks, 38.0ms
# Speed: 3.8ms preprocess, 38.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 5 motorcycles, 2 trucks, 38.2ms
# Speed: 4.0ms preprocess, 38.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 4 motorcycles, 1 truck, 38.0ms
# Speed: 2.2ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 4 motorcycles, 1 truck, 38.0ms
# Speed: 2.9ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 cars, 5 motorcycles, 1 truck, 38.2ms
# Speed: 3.2ms preprocess, 38.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 8 cars, 4 motorcycles, 1 truck, 38.1ms
# Speed: 2.1ms preprocess, 38.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 5 motorcycles, 1 truck, 38.2ms
# Speed: 3.5ms preprocess, 38.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 4 motorcycles, 1 truck, 38.0ms
# Speed: 2.6ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 5 motorcycles, 38.1ms
# Speed: 2.1ms preprocess, 38.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 cars, 6 motorcycles, 1 truck, 38.1ms
# Speed: 3.0ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 9 cars, 5 motorcycles, 1 truck, 38.0ms
# Speed: 2.5ms preprocess, 38.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 cars, 8 motorcycles, 1 truck, 38.2ms
# Speed: 2.7ms preprocess, 38.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 5 motorcycles, 2 trucks, 38.2ms
# Speed: 3.0ms preprocess, 38.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 bicycle, 6 cars, 7 motorcycles, 1 truck, 38.2ms
# Speed: 3.1ms preprocess, 38.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 cars, 4 motorcycles, 1 truck, 37.9ms
# Speed: 2.2ms preprocess, 37.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 bicycle, 6 cars, 6 motorcycles, 1 truck, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 8 cars, 7 motorcycles, 1 truck, 38.0ms
# Speed: 2.1ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 bicycle, 7 cars, 5 motorcycles, 1 truck, 38.0ms
# Speed: 2.6ms preprocess, 38.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 cars, 6 motorcycles, 3 trucks, 38.1ms
# Speed: 2.2ms preprocess, 38.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 6 motorcycles, 4 trucks, 38.0ms
# Speed: 2.1ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 9 cars, 6 motorcycles, 2 trucks, 38.1ms
# Speed: 2.1ms preprocess, 38.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 9 cars, 6 motorcycles, 3 trucks, 1 backpack, 37.9ms
# Speed: 2.0ms preprocess, 37.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 8 cars, 6 motorcycles, 2 trucks, 1 backpack, 38.2ms
# Speed: 2.4ms preprocess, 38.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 cars, 6 motorcycles, 1 bus, 1 truck, 1 backpack, 38.0ms
# Speed: 3.1ms preprocess, 38.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 cars, 6 motorcycles, 1 truck, 1 backpack, 38.1ms
# Speed: 3.1ms preprocess, 38.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 6 motorcycles, 1 bus, 2 trucks, 1 backpack, 38.0ms
# Speed: 3.6ms preprocess, 38.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 6 motorcycles, 2 trucks, 1 backpack, 38.0ms
# Speed: 3.4ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 3 motorcycles, 2 trucks, 38.0ms
# Speed: 2.2ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 4 motorcycles, 1 truck, 1 backpack, 37.9ms
# Speed: 1.9ms preprocess, 37.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 5 motorcycles, 1 truck, 1 backpack, 38.0ms
# Speed: 1.9ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 8 cars, 5 motorcycles, 1 truck, 1 backpack, 37.9ms
# Speed: 1.7ms preprocess, 37.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 4 motorcycles, 1 truck, 2 backpacks, 38.0ms
# Speed: 1.8ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 4 motorcycles, 2 trucks, 2 backpacks, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 5 motorcycles, 1 truck, 1 backpack, 38.1ms
# Speed: 2.7ms preprocess, 38.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 6 motorcycles, 1 truck, 1 backpack, 38.0ms
# Speed: 2.5ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 6 motorcycles, 1 truck, 2 backpacks, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 5 motorcycles, 1 truck, 2 backpacks, 37.9ms
# Speed: 1.7ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 4 motorcycles, 1 truck, 1 backpack, 38.1ms
# Speed: 2.4ms preprocess, 38.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 6 motorcycles, 1 truck, 2 backpacks, 38.3ms
# Speed: 3.8ms preprocess, 38.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 7 cars, 4 motorcycles, 2 trucks, 2 backpacks, 38.2ms
# Speed: 2.8ms preprocess, 38.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 6 motorcycles, 2 trucks, 1 backpack, 38.0ms
# Speed: 2.5ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 7 motorcycles, 3 trucks, 1 backpack, 38.2ms
# Speed: 1.9ms preprocess, 38.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 5 motorcycles, 2 trucks, 1 backpack, 38.0ms
# Speed: 1.9ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 5 motorcycles, 2 trucks, 38.0ms
# Speed: 2.7ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 6 cars, 6 motorcycles, 3 trucks, 2 backpacks, 38.1ms
# Speed: 2.4ms preprocess, 38.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 6 motorcycles, 2 trucks, 38.0ms
# Speed: 2.6ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 5 motorcycles, 3 trucks, 38.1ms
# Speed: 1.9ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 5 motorcycles, 2 trucks, 38.1ms
# Speed: 2.7ms preprocess, 38.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 6 motorcycles, 3 trucks, 37.9ms
# Speed: 1.9ms preprocess, 37.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 5 motorcycles, 2 trucks, 38.0ms
# Speed: 2.1ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 6 motorcycles, 1 truck, 37.9ms
# Speed: 1.8ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 5 motorcycles, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 6 motorcycles, 37.9ms
# Speed: 1.9ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 5 motorcycles, 38.1ms
# Speed: 1.9ms preprocess, 38.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 4 motorcycles, 38.0ms
# Speed: 2.6ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 4 motorcycles, 38.0ms
# Speed: 2.6ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 4 motorcycles, 38.0ms
# Speed: 1.6ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 4 motorcycles, 38.0ms
# Speed: 2.1ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 4 motorcycles, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 4 motorcycles, 1 truck, 37.9ms
# Speed: 1.9ms preprocess, 37.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 4 motorcycles, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 5 motorcycles, 1 truck, 38.3ms
# Speed: 3.7ms preprocess, 38.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 6 motorcycles, 2 trucks, 38.0ms
# Speed: 2.1ms preprocess, 38.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 5 motorcycles, 1 truck, 38.0ms
# Speed: 2.8ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 4 motorcycles, 1 truck, 38.3ms
# Speed: 2.9ms preprocess, 38.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 4 motorcycles, 1 truck, 38.0ms
# Speed: 2.5ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 4 motorcycles, 1 truck, 37.9ms
# Speed: 1.7ms preprocess, 37.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 10 cars, 4 motorcycles, 1 truck, 38.0ms
# Speed: 1.8ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 4 motorcycles, 1 truck, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 5 motorcycles, 38.1ms
# Speed: 1.9ms preprocess, 38.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 11 cars, 3 motorcycles, 38.0ms
# Speed: 2.2ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 3 motorcycles, 37.9ms
# Speed: 1.8ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 2 motorcycles, 1 truck, 38.1ms
# Speed: 1.9ms preprocess, 38.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 2 motorcycles, 1 truck, 37.9ms
# Speed: 1.9ms preprocess, 37.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 2 motorcycles, 2 trucks, 38.1ms
# Speed: 2.8ms preprocess, 38.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 2 motorcycles, 1 truck, 37.9ms
# Speed: 1.7ms preprocess, 37.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 3 motorcycles, 1 truck, 37.9ms
# Speed: 2.5ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 5 cars, 2 motorcycles, 1 truck, 38.0ms
# Speed: 2.8ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 2 motorcycles, 1 truck, 38.0ms
# Speed: 3.3ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 2 motorcycles, 2 trucks, 37.9ms
# Speed: 1.9ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 3 motorcycles, 2 trucks, 38.0ms
# Speed: 1.9ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 2 motorcycles, 2 trucks, 38.6ms
# Speed: 3.1ms preprocess, 38.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 2 motorcycles, 38.2ms
# Speed: 2.0ms preprocess, 38.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 4 motorcycles, 38.1ms
# Speed: 12.3ms preprocess, 38.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 4 motorcycles, 38.0ms
# Speed: 2.2ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 5 motorcycles, 1 truck, 37.9ms
# Speed: 2.1ms preprocess, 37.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 5 motorcycles, 1 truck, 38.0ms
# Speed: 1.8ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 4 motorcycles, 38.0ms
# Speed: 3.3ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 4 motorcycles, 1 truck, 38.1ms
# Speed: 2.0ms preprocess, 38.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 4 motorcycles, 38.0ms
# Speed: 3.0ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 cars, 4 motorcycles, 38.1ms
# Speed: 3.3ms preprocess, 38.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 10 cars, 4 motorcycles, 38.1ms
# Speed: 1.8ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 cars, 4 motorcycles, 38.1ms
# Speed: 2.9ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 5 motorcycles, 38.1ms
# Speed: 2.2ms preprocess, 38.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 4 motorcycles, 38.0ms
# Speed: 2.4ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 10 cars, 2 motorcycles, 38.0ms
# Speed: 2.9ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 10 cars, 4 motorcycles, 1 truck, 38.1ms
# Speed: 2.9ms preprocess, 38.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 11 cars, 3 motorcycles, 38.0ms
# Speed: 2.5ms preprocess, 38.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 11 cars, 3 motorcycles, 38.1ms
# Speed: 3.1ms preprocess, 38.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 3 motorcycles, 1 bus, 38.1ms
# Speed: 1.8ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 6 cars, 3 motorcycles, 1 bus, 38.1ms
# Speed: 3.5ms preprocess, 38.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 2 motorcycles, 1 bus, 37.9ms
# Speed: 2.1ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 4 motorcycles, 38.0ms
# Speed: 3.0ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 4 motorcycles, 1 truck, 38.0ms
# Speed: 2.7ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 4 motorcycles, 1 truck, 38.0ms
# Speed: 1.9ms preprocess, 38.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 7 cars, 4 motorcycles, 1 truck, 38.1ms
# Speed: 3.5ms preprocess, 38.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 cars, 4 motorcycles, 1 truck, 38.1ms
# Speed: 2.5ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 3 motorcycles, 1 truck, 38.1ms
# Speed: 3.0ms preprocess, 38.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 3 motorcycles, 1 truck, 37.9ms
# Speed: 1.9ms preprocess, 37.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 3 motorcycles, 38.0ms
# Speed: 2.2ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 cars, 3 motorcycles, 1 truck, 38.0ms
# Speed: 2.1ms preprocess, 38.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 cars, 3 motorcycles, 38.0ms
# Speed: 3.7ms preprocess, 38.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 cars, 3 motorcycles, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 9 cars, 3 motorcycles, 38.1ms
# Speed: 2.3ms preprocess, 38.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 cars, 3 motorcycles, 1 truck, 38.0ms
# Speed: 2.6ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 3 motorcycles, 1 truck, 38.0ms
# Speed: 2.4ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 3 motorcycles, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 3 motorcycles, 38.1ms
# Speed: 3.1ms preprocess, 38.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 3 motorcycles, 2 trucks, 38.1ms
# Speed: 2.4ms preprocess, 38.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 4 motorcycles, 2 trucks, 37.9ms
# Speed: 1.8ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 3 motorcycles, 2 trucks, 38.2ms
# Speed: 2.9ms preprocess, 38.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 4 motorcycles, 2 trucks, 38.0ms
# Speed: 2.2ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 2 motorcycles, 1 truck, 38.0ms
# Speed: 1.8ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 3 motorcycles, 1 truck, 37.9ms
# Speed: 2.0ms preprocess, 37.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 2 motorcycles, 1 truck, 38.0ms
# Speed: 1.8ms preprocess, 38.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 3 motorcycles, 1 truck, 38.0ms
# Speed: 2.9ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 9 cars, 2 motorcycles, 38.0ms
# Speed: 2.3ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 motorcycles, 1 truck, 38.2ms
# Speed: 2.8ms preprocess, 38.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 cars, 3 motorcycles, 1 truck, 37.9ms
# Speed: 2.3ms preprocess, 37.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 11 cars, 2 motorcycles, 38.1ms
# Speed: 3.4ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 2 motorcycles, 1 truck, 38.0ms
# Speed: 2.2ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 cars, 2 motorcycles, 1 truck, 38.0ms
# Speed: 2.4ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 2 motorcycles, 1 truck, 38.1ms
# Speed: 2.2ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 2 motorcycles, 1 truck, 38.0ms
# Speed: 2.3ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 2 motorcycles, 37.9ms
# Speed: 1.9ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 cars, 2 motorcycles, 38.0ms
# Speed: 1.8ms preprocess, 38.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 8 cars, 2 motorcycles, 38.0ms
# Speed: 3.1ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 2 motorcycles, 38.0ms
# Speed: 3.1ms preprocess, 38.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 2 motorcycles, 1 potted plant, 38.0ms
# Speed: 2.3ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 2 motorcycles, 38.0ms
# Speed: 2.2ms preprocess, 38.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 2 motorcycles, 37.9ms
# Speed: 1.8ms preprocess, 37.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 cars, 2 motorcycles, 38.5ms
# Speed: 2.0ms preprocess, 38.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 2 motorcycles, 38.0ms
# Speed: 2.7ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 3 motorcycles, 38.3ms
# Speed: 2.3ms preprocess, 38.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 6 cars, 2 motorcycles, 38.0ms
# Speed: 3.0ms preprocess, 38.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 3 motorcycles, 38.1ms
# Speed: 2.4ms preprocess, 38.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 4 motorcycles, 1 bus, 1 truck, 38.3ms
# Speed: 1.8ms preprocess, 38.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 3 motorcycles, 1 bus, 1 truck, 38.3ms
# Speed: 2.5ms preprocess, 38.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 6 cars, 4 motorcycles, 1 truck, 38.0ms
# Speed: 2.4ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 8 cars, 4 motorcycles, 2 trucks, 38.4ms
# Speed: 2.5ms preprocess, 38.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 10 cars, 4 motorcycles, 1 truck, 38.2ms
# Speed: 2.5ms preprocess, 38.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 3 motorcycles, 38.2ms
# Speed: 4.3ms preprocess, 38.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 4 motorcycles, 38.1ms
# Speed: 3.1ms preprocess, 38.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 9 cars, 3 motorcycles, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 3 motorcycles, 38.3ms
# Speed: 1.7ms preprocess, 38.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 7 cars, 4 motorcycles, 1 truck, 38.0ms
# Speed: 2.2ms preprocess, 38.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8 cars, 3 motorcycles, 1 truck, 38.2ms
# Speed: 2.0ms preprocess, 38.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 23

# %%
tracker_sort_rcnn(input_path,output_path4)
